# %% [markdown]
# # 1. Import and Install Dependencies

# %%
# !pip install mediapipe
# Out:
# Requirement already satisfied: mediapipe in c:\users\dell\appdata\roaming\python\python39\site-packages (0.8.11)
# Requirement already satisfied: absl-py in c:\users\dell\anaconda3\lib\site-packages (from mediapipe) (1.3.0)
# Requirement already satisfied: attrs>=19.1.0 in c:\users\dell\anaconda3\lib\site-packages (from mediapipe) (21.4.0)
# Requirement already satisfied: matplotlib in c:\users\dell\anaconda3\lib\site-packages (from mediapipe) (3.5.2)
# Requirement already satisfied: numpy in c:\users\dell\anaconda3\lib\site-packages (from mediapipe) (1.21.5)
# Requirement already satisfied: protobuf<4,>=3.11 in c:\users\dell\anaconda3\lib\site-packages (from mediapipe) (3.19.6)
# Requirement already satisfied: opencv-contrib-python in c:\users\dell\appdata\roaming\python\python39\site-packages (from mediapipe) (4.6.0.66)
# Requirement already satisfied: cycler>=0.10 in c:\users\dell\anaconda3\lib\site-packages (from matplotlib->mediapipe) (0.11.0)
# Requirement already satisfied: pillow>=6.2.0 in c:\users\dell\anaconda3\lib\site-packages (from matplotlib->mediapipe) (9.2.0)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\dell\anaconda3\lib\site-packages (from matplotlib->mediapipe) (2.8.2)
# Requirement already satisfied: packaging>=20.0 in c:\users\dell\anaconda3\lib\site-packages (from matplotlib->mediapipe) (21.3)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\dell\anaconda3\lib\site-packages (from matplotlib->mediapipe) (4.25.0)
# Requirement already satisfied: pyparsing>=2.2.1 in c:\users\dell\anaconda3\lib\site-packages (from matplotlib->mediapipe) (3.0.9)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\users\dell\anaconda3\lib\site-packages (from matplotlib->mediapipe) (1.4.2)
# Requirement already satisfied: six>=1.5 in c:\users\dell\anaconda3\lib\site-packages (from python-dateutil>=2.7->matplotlib->mediapipe) (1.16.0)

# %%
import cv2
import numpy as np
import os
from matplotlib import pyplot as plt
import time
import mediapipe as mp

# %% [markdown]
# # 2. Keypoints using MP Holistic

# %%
mp_holistic = mp.solutions.holistic # Holistic model
mp_drawing = mp.solutions.drawing_utils # Drawing utilities

# %%
def mediapipe_detection(image, model):
    image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB) # COLOR CONVERSION BGR 2 RGB
    image.flags.writeable = False                  # Image is no longer writeable
    results = model.process(image)                 # Make prediction
    image.flags.writeable = True                   # Image is now writeable 
    image = cv2.cvtColor(image, cv2.COLOR_RGB2BGR) # COLOR COVERSION RGB 2 BGR
    return image, results

# %%
def draw_landmarks(image, results):
#     mp_drawing.draw_landmarks(image, results.face_landmarks, mp_holistic.FACEMESH_TESSELATION) # Draw face connections
    #mp_drawing.draw_landmarks(image, results.pose_landmarks, mp_holistic.POSE_CONNECTIONS) # Draw pose connections
    mp_drawing.draw_landmarks(image, results.left_hand_landmarks, mp_holistic.HAND_CONNECTIONS) # Draw left hand connections
    mp_drawing.draw_landmarks(image, results.right_hand_landmarks, mp_holistic.HAND_CONNECTIONS) # Draw right hand connections

# %%
def draw_styled_landmarks(image, results):
    # Draw face connections
    #mp_drawing.draw_landmarks(image, results.face_landmarks, mp_holistic.FACEMESH_TESSELATION, 
     #                        mp_drawing.DrawingSpec(color=(80,110,10), thickness=1, circle_radius=1), 
      #                       mp_drawing.DrawingSpec(color=(80,256,121), thickness=1, circle_radius=1)
       #                      ) 
    # Draw pose connections
#     mp_drawing.draw_landmarks(image, results.pose_landmarks, mp_holistic.POSE_CONNECTIONS,
#                              mp_drawing.DrawingSpec(color=(80,22,10), thickness=2, circle_radius=4), 
#                              mp_drawing.DrawingSpec(color=(80,44,121), thickness=2, circle_radius=2)
#                              ) 
    # Draw left hand connections
    mp_drawing.draw_landmarks(image, results.left_hand_landmarks, mp_holistic.HAND_CONNECTIONS, 
                             mp_drawing.DrawingSpec(color=(121,22,76), thickness=2, circle_radius=4), 
                             mp_drawing.DrawingSpec(color=(121,44,250), thickness=2, circle_radius=2)
                             ) 
    # Draw right hand connections  
    mp_drawing.draw_landmarks(image, results.right_hand_landmarks, mp_holistic.HAND_CONNECTIONS, 
                             mp_drawing.DrawingSpec(color=(245,117,66), thickness=2, circle_radius=4), 
                             mp_drawing.DrawingSpec(color=(245,66,230), thickness=2, circle_radius=2)
                             )

# %%
cap = cv2.VideoCapture(0)
# Set mediapipe model 
with mp_holistic.Holistic(min_detection_confidence=0.5, min_tracking_confidence=0.5) as holistic:
    while cap.isOpened():

        # Read feed
        ret, frame = cap.read()

        # Make detections
        image, results = mediapipe_detection(frame, holistic)
        print(results)
        
        # Draw landmarks
        draw_styled_landmarks(image, results)

        # Show to screen
        cv2.imshow('OpenCV Feed', image)

        # Break gracefully
        if cv2.waitKey(10) & 0xFF == ord('q'):
            break
    cap.release()
    cv2.destroyAllWindows()
# Out:
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>

# %%
draw_landmarks(frame, results)

# %%
plt.imshow(cv2.cvtColor(frame, cv2.COLOR_BGR2RGB))

# %% [markdown]
# # 3. Extract Keypoint Values

# %%
len(results.left_hand_landmarks.landmark)
# Out:
# 21

# %%
pose = []
for res in results.pose_landmarks.landmark:
    test = np.array([res.x, res.y, res.z, res.visibility])
    pose.append(test)

# %%
#pose = np.array([[res.x, res.y, res.z, res.visibility] for res in results.pose_landmarks.landmark]).flatten() if results.pose_landmarks else np.zeros(132)
#face = np.array([[res.x, res.y, res.z] for res in results.face_landmarks.landmark]).flatten() if results.face_landmarks else np.zeros(1404)
lh = np.array([[res.x, res.y, res.z] for res in results.left_hand_landmarks.landmark]).flatten() if results.left_hand_landmarks else np.zeros(21*3)
rh = np.array([[res.x, res.y, res.z] for res in results.right_hand_landmarks.landmark]).flatten() if results.right_hand_landmarks else np.zeros(21*3)

# %%
#face = np.array([[res.x, res.y, res.z] for res in results.face_landmarks.landmark]).flatten() if results.face_landmarks else np.zeros(1404)

# %%
def extract_keypoints(results):
    #pose = np.array([[res.x, res.y, res.z, res.visibility] for res in results.pose_landmarks.landmark]).flatten() if results.pose_landmarks else np.zeros(33*4)
    #face = np.array([[res.x, res.y, res.z] for res in results.face_landmarks.landmark]).flatten() if results.face_landmarks else np.zeros(468*3)
    lh = np.array([[res.x, res.y, res.z] for res in results.left_hand_landmarks.landmark]).flatten() if results.left_hand_landmarks else np.zeros(21*3)
    rh = np.array([[res.x, res.y, res.z] for res in results.right_hand_landmarks.landmark]).flatten() if results.right_hand_landmarks else np.zeros(21*3)
    return np.concatenate([ lh, rh])

# %%
result_test = extract_keypoints(results)

# %%
result_test
# Out:
# array([ 8.31526518e-01,  8.36496413e-01,  6.36187792e-07,  7.16411829e-01,
#         8.09353113e-01, -2.70973518e-02,  6.01565063e-01,  7.29308367e-01,
#        -4.42881584e-02,  5.16843557e-01,  6.80552423e-01, -6.39308169e-02,
#         4.42703664e-01,  6.77056193e-01, -8.48941505e-02,  6.39427900e-01,
#         4.92459148e-01, -3.59658059e-03,  5.90964198e-01,  3.53032887e-01,
#        -2.75788419e-02,  5.67244232e-01,  2.68229395e-01, -5.45323119e-02,
#         5.49472511e-01,  1.88832253e-01, -7.71029964e-02,  6.96454823e-01,
#         4.53836113e-01, -1.92319155e-02,  6.45351768e-01,  2.97018528e-01,
#        -3.80888209e-02,  6.17826045e-01,  1.97043419e-01, -6.24003485e-02,
#         5.93356252e-01,  1.09070659e-01, -8.31674188e-02,  7.60924041e-01,
#         4.45611060e-01, -4.18736078e-02,  7.21130431e-01,  2.92332411e-01,
#        -6.27575740e-02,  6.97491229e-01,  1.99232459e-01, -7.97058791e-02,
#         6.71459556e-01,  1.16661400e-01, -9.45804864e-02,  8.31206322e-01,
#         4.62764055e-01, -6.89673349e-02,  8.07922781e-01,  3.41802448e-01,
#        -8.77647027e-02,  7.90148377e-01,  2.60293543e-01, -9.57385227e-02,
#         7.69285500e-01,  1.84501559e-01, -1.03588484e-01,  0.00000000e+00,
#         0.00000000e+00,  0.00000000e+00,  0.00000000e+00,  0.00000000e+00,
#         0.00000000e+00,  0.00000000e+00,  0.00000000e+00,  0.00000000e+00,
#         0.00000000e+00,  0.00000000e+00,  0.00000000e+00,  0.00000000e+00,
#         0.00000000e+00,  0.00000000e+00,  0.00000000e+00,  0.00000000e+00,
#         0.00000000e+00,  0.00000000e+00,  0.00000000e+00,  0.00000000e+00,
#         0.00000000e+00,  0.00000000e+00,  0.00000000e+00,  0.00000000e+00,
#         0.00000000e+00,  0.00000000e+00,  0.00000000e+00,  0.00000000e+00,
#         0.00000000e+00,  0.00000000e+00,  0.00000000e+00,  0.00000000e+00,
#         0.00000000e+00,  0.00000000e+00,  0.00000000e+00,  0.00000000e+00,
#         0.00000000e+00,  0.00000000e+00,  0.00000000e+00,  0.00000000e+00,
#         0.00000000e+00,  0.00000000e+00,  0.00000000e+00,  0.00000000e+00,
#         0.00000000e+00,  0.00000000e+00,  0.00000000e+00,  0.00000000e+00,
#         0.00000000e+00,  0.00000000e+00,  0.00000000e+00,  0.00000000e+00,
#         0.00000000e+00,  0.00000000e+00,  0.00000000e+00,  0.00000000e+00,
#         0.00000000e+00,  0.00000000e+00,  0.00000000e+00,  0.00000000e+00,
#         0.00000000e+00,  0.00000000e+00])

# %%
np.save('0', result_test)

# %%
np.load('0.npy')
# Out:
# array([ 8.31526518e-01,  8.36496413e-01,  6.36187792e-07,  7.16411829e-01,
#         8.09353113e-01, -2.70973518e-02,  6.01565063e-01,  7.29308367e-01,
#        -4.42881584e-02,  5.16843557e-01,  6.80552423e-01, -6.39308169e-02,
#         4.42703664e-01,  6.77056193e-01, -8.48941505e-02,  6.39427900e-01,
#         4.92459148e-01, -3.59658059e-03,  5.90964198e-01,  3.53032887e-01,
#        -2.75788419e-02,  5.67244232e-01,  2.68229395e-01, -5.45323119e-02,
#         5.49472511e-01,  1.88832253e-01, -7.71029964e-02,  6.96454823e-01,
#         4.53836113e-01, -1.92319155e-02,  6.45351768e-01,  2.97018528e-01,
#        -3.80888209e-02,  6.17826045e-01,  1.97043419e-01, -6.24003485e-02,
#         5.93356252e-01,  1.09070659e-01, -8.31674188e-02,  7.60924041e-01,
#         4.45611060e-01, -4.18736078e-02,  7.21130431e-01,  2.92332411e-01,
#        -6.27575740e-02,  6.97491229e-01,  1.99232459e-01, -7.97058791e-02,
#         6.71459556e-01,  1.16661400e-01, -9.45804864e-02,  8.31206322e-01,
#         4.62764055e-01, -6.89673349e-02,  8.07922781e-01,  3.41802448e-01,
#        -8.77647027e-02,  7.90148377e-01,  2.60293543e-01, -9.57385227e-02,
#         7.69285500e-01,  1.84501559e-01, -1.03588484e-01,  0.00000000e+00,
#         0.00000000e+00,  0.00000000e+00,  0.00000000e+00,  0.00000000e+00,
#         0.00000000e+00,  0.00000000e+00,  0.00000000e+00,  0.00000000e+00,
#         0.00000000e+00,  0.00000000e+00,  0.00000000e+00,  0.00000000e+00,
#         0.00000000e+00,  0.00000000e+00,  0.00000000e+00,  0.00000000e+00,
#         0.00000000e+00,  0.00000000e+00,  0.00000000e+00,  0.00000000e+00,
#         0.00000000e+00,  0.00000000e+00,  0.00000000e+00,  0.00000000e+00,
#         0.00000000e+00,  0.00000000e+00,  0.00000000e+00,  0.00000000e+00,
#         0.00000000e+00,  0.00000000e+00,  0.00000000e+00,  0.00000000e+00,
#         0.00000000e+00,  0.00000000e+00,  0.00000000e+00,  0.00000000e+00,
#         0.00000000e+00,  0.00000000e+00,  0.00000000e+00,  0.00000000e+00,
#         0.00000000e+00,  0.00000000e+00,  0.00000000e+00,  0.00000000e+00,
#         0.00000000e+00,  0.00000000e+00,  0.00000000e+00,  0.00000000e+00,
#         0.00000000e+00,  0.00000000e+00,  0.00000000e+00,  0.00000000e+00,
#         0.00000000e+00,  0.00000000e+00,  0.00000000e+00,  0.00000000e+00,
#         0.00000000e+00,  0.00000000e+00,  0.00000000e+00,  0.00000000e+00,
#         0.00000000e+00,  0.00000000e+00])

# %% [markdown]
# # 4. Setup Folders for Collection

# %%
# Path for exported data, numpy arrays
DATA_PATH = os.path.join('MP_Data') 

# Actions that we try to detect
actions = np.array(['hello','thanks','you','sorry','no','iloveyou','yes','Luck'])

# Thirty videos worth of data
no_sequences = 30

# Videos are going to be 30 frames in length
sequence_length = 30

# Folder start
# start_folder = 30

# %%
for action in actions: 
#     dirmax = np.max(np.array(os.listdir(os.path.join(DATA_PATH, action))).astype(int))
    for sequence in range(1,no_sequences+1):
        try: 
            os.makedirs(os.path.join(DATA_PATH, action, str(sequence)))
        except:
            pass

# %% [markdown]
# # 5. Collect Keypoint Values for Training and Testing

# %%
cap = cv2.VideoCapture(0)
# Set mediapipe model 
with mp_holistic.Holistic(min_detection_confidence=0.5, min_tracking_confidence=0.5) as holistic:
    
    # NEW LOOP
    # Loop through actions
    for action in actions:
        # Loop through sequences aka videos
        for sequence in range(1,no_sequences+1):
            # Loop through video length aka sequence length
            for frame_num in range(sequence_length):

                # Read feed
                ret, frame = cap.read()

                # Make detections
                image, results = mediapipe_detection(frame, holistic)

                # Draw landmarks
                draw_styled_landmarks(image, results)
                
                # NEW Apply wait logic
                if frame_num == 0: 
                    cv2.putText(image, 'STARTING COLLECTION', (120,200), 
                               cv2.FONT_HERSHEY_SIMPLEX, 1, (0,255, 0), 4, cv2.LINE_AA)
                    cv2.putText(image, 'Collecting frames for {} Video Number {}'.format(action, sequence), (15,12), 
                               cv2.FONT_HERSHEY_SIMPLEX, 0.5, (0, 0, 255), 1, cv2.LINE_AA)
                    # Show to screen
                    cv2.imshow('OpenCV Feed', image) 
                    cv2.waitKey(500)
                else: 
                    cv2.putText(image, 'Collecting frames for {} Video Number {}'.format(action, sequence), (15,12), 
                               cv2.FONT_HERSHEY_SIMPLEX, 0.5, (0, 0, 255), 1, cv2.LINE_AA)
                    # Show to screen
                    cv2.imshow('OpenCV Feed', image)
                
                # NEW Export keypoints
                keypoints = extract_keypoints(results)
                npy_path = os.path.join(DATA_PATH, action, str(sequence), str(frame_num))
                np.save(npy_path, keypoints)

                # Break gracefully
                if cv2.waitKey(10) & 0xFF == ord('q'):
                    break
                    
    cap.release()
    cv2.destroyAllWindows()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_11416\1419164182.py in <module>
#       5     # NEW LOOP
#       6     # Loop through actions
# ----> 7     for action in actions:
#       8         # Loop through sequences aka videos
#       9         for sequence in range(1,no_sequences+1):
#
# NameError: name 'actions' is not defined

# %%
cap.release()
cv2.destroyAllWindows()

# %% [markdown]
# # 6. Preprocess Data and Create Labels and Features

# %%
from sklearn.model_selection import train_test_split
from tensorflow.keras.utils import to_categorical

# %%
label_map = {label:num for num, label in enumerate(actions)}

# %%
label_map
# Out:
# {'hello': 0,
#  'thanks': 1,
#  'you': 2,
#  'sorry': 3,
#  'no': 4,
#  'iloveyou': 5,
#  'yes': 6,
#  'Luck': 7}

# %%
sequences, labels = [], []
for action in actions:
    for sequence in np.array(os.listdir(os.path.join(DATA_PATH, action))).astype(int):
        window = []
        for frame_num in range(sequence_length):
            res = np.load(os.path.join(DATA_PATH, action, str(sequence), "{}.npy".format(frame_num)))
            window.append(res)
        sequences.append(window)
        labels.append(label_map[action])

# %%
np.array(sequences).shape
# Out:
# (240, 30, 126)

# %%
np.array(labels).shape
# Out:
# (240,)

# %%
X = np.array(sequences)

# %%
X.shape
# Out:
# (240, 30, 126)

# %%
y = to_categorical(labels).astype(int)

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.05)

# %%
y_test.shape
# Out:
# (12, 8)

# %% [markdown]
# # 7. Build and Train LSTM Neural Network

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, Dense
from tensorflow.keras.callbacks import TensorBoard

# %%
log_dir = os.path.join('Logs')
tb_callback = TensorBoard(log_dir=log_dir)

# %%
model = Sequential()
model.add(LSTM(64, return_sequences=True, activation='relu', input_shape=(30,126)))
model.add(LSTM(128, return_sequences=True, activation='relu'))
model.add(LSTM(64, return_sequences=False, activation='relu'))
model.add(Dense(64, activation='relu'))
model.add(Dense(32, activation='relu'))
# model.add(Dense(16, activation='relu'))
model.add(Dense(actions.shape[0], activation='softmax'))

# %%
# callback = tensorflow.keras.callbacks.EarlyStopping(patience=5, restore_best_weights=True)

# %%
model.compile(optimizer='Adam', loss='categorical_crossentropy', metrics=['categorical_accuracy'])

# %%
model.fit(X_train, y_train, epochs=1000, callbacks=[tb_callback])
# Out:
# Epoch 1/1000
# 8/8 [==============================] - 5s 53ms/step - loss: 2.0446 - categorical_accuracy: 0.2281
# Epoch 2/1000
# 8/8 [==============================] - 0s 59ms/step - loss: 1.8234 - categorical_accuracy: 0.2500
# Epoch 3/1000
# 8/8 [==============================] - 1s 76ms/step - loss: 1.7343 - categorical_accuracy: 0.2632
# Epoch 4/1000
# 8/8 [==============================] - 1s 77ms/step - loss: 1.7275 - categorical_accuracy: 0.2851
# Epoch 5/1000
# 8/8 [==============================] - 1s 77ms/step - loss: 1.6914 - categorical_accuracy: 0.3158
# Epoch 6/1000
# 8/8 [==============================] - 1s 77ms/step - loss: 1.6758 - categorical_accuracy: 0.2982
# Epoch 7/1000
# 8/8 [==============================] - 1s 78ms/step - loss: 1.6425 - categorical_accuracy: 0.3289
# Epoch 8/1000
# 8/8 [==============================] - 1s 77ms/step - loss: 1.5788 - categorical_accuracy: 0.3991
# Epoch 9/1000
# 8/8 [==============================] - 1s 75ms/step - loss: 1.5467 - categorical_accuracy: 0.3772
# Epoch 10/1000
# 8/8 [==============================] - 1s 76ms/step - loss: 1.5446 - categorical_accuracy: 0.4912
# Epoch 11/1000
# 8/8 [==============================] - 1s 77ms/step - loss: 1.3369 - categorical_accuracy: 0.4430
# Epoch 12/1000
# 8/8 [==============================] - 1s 77ms/step - loss: 2.8864 - categorical_accuracy: 0.4079
# Epoch 13/1000
# 8/8 [==============================] - 1s 76ms/step - loss: 2.5476 - categorical_accuracy: 0.2500
# Epoch 14/1000
# 8/8 [==============================] - 1s 71ms/step - loss: 1.7322 - categorical_accuracy: 0.3991
# Epoch 15/1000
# 8/8 [==============================] - 1s 73ms/step - loss: 1.7412 - categorical_accuracy: 0.3421
# Epoch 16/1000
# 8/8 [==============================] - 1s 76ms/step - loss: 1.7106 - categorical_accuracy: 0.3158
# Epoch 17/1000
# 8/8 [==============================] - 1s 77ms/step - loss: 1.6471 - categorical_accuracy: 0.3728
# Epoch 18/1000
# 8/8 [==============================] - 1s 77ms/step - loss: 1.5518 - categorical_accuracy: 0.3816
# Epoch 19/1000
# 8/8 [==============================] - 1s 76ms/step - loss: 1.4222 - categorical_accuracy: 0.4430
# Epoch 20/1000
# 8/8 [==============================] - 0s 55ms/step - loss: 1.3377 - categorical_accuracy: 0.4781
# Epoch 21/1000
# 8/8 [==============================] - 0s 48ms/step - loss: 1.3240 - categorical_accuracy: 0.4781
# Epoch 22/1000
# 8/8 [==============================] - 0s 53ms/step - loss: 1.2223 - categorical_accuracy: 0.5088
# Epoch 23/1000
# 8/8 [==============================] - 0s 51ms/step - loss: 1.0756 - categorical_accuracy: 0.5833
# Epoch 24/1000
# 8/8 [==============================] - 0s 53ms/step - loss: 1.0321 - categorical_accuracy: 0.5526
# Epoch 25/1000
# 8/8 [==============================] - 0s 51ms/step - loss: 1.4299 - categorical_accuracy: 0.3596
# Epoch 26/1000
# 8/8 [==============================] - 0s 51ms/step - loss: 1.3005 - categorical_accuracy: 0.4781
# Epoch 27/1000
# 8/8 [==============================] - 0s 48ms/step - loss: 1.1838 - categorical_accuracy: 0.5833
# Epoch 28/1000
# 8/8 [==============================] - 0s 50ms/step - loss: 1.1370 - categorical_accuracy: 0.6009
# Epoch 29/1000
# 8/8 [==============================] - 1s 77ms/step - loss: 1.1260 - categorical_accuracy: 0.5570
# Epoch 30/1000
# 8/8 [==============================] - 1s 74ms/step - loss: 1.0100 - categorical_accuracy: 0.5614
# Epoch 31/1000
# 8/8 [==============================] - 1s 76ms/step - loss: 0.8921 - categorical_accuracy: 0.6053
# Epoch 32/1000
# 8/8 [==============================] - 1s 76ms/step - loss: 0.7999 - categorical_accuracy: 0.6053
# Epoch 33/1000
# 8/8 [==============================] - 1s 76ms/step - loss: 0.8216 - categorical_accuracy: 0.6228
# Epoch 34/1000
# 8/8 [==============================] - 1s 77ms/step - loss: 0.8036 - categorical_accuracy: 0.6447
# Epoch 35/1000
# 8/8 [==============================] - 1s 75ms/step - loss: 0.7053 - categorical_accuracy: 0.6798
# Epoch 36/1000
# 8/8 [==============================] - 1s 76ms/step - loss: 0.6174 - categorical_accuracy: 0.7325
# Epoch 37/1000
# 8/8 [==============================] - 1s 76ms/step - loss: 0.5703 - categorical_accuracy: 0.7851
# Epoch 38/1000
# 8/8 [==============================] - 1s 76ms/step - loss: 0.6967 - categorical_accuracy: 0.7105
# Epoch 39/1000
# 8/8 [==============================] - 1s 76ms/step - loss: 0.6000 - categorical_accuracy: 0.7675
# Epoch 40/1000
# 8/8 [==============================] - 0s 58ms/step - loss: 0.6902 - categorical_accuracy: 0.6930
# Epoch 41/1000
# 8/8 [==============================] - 0s 49ms/step - loss: 0.5996 - categorical_accuracy: 0.7675
# Epoch 42/1000
# 8/8 [==============================] - 0s 62ms/step - loss: 0.6524 - categorical_accuracy: 0.6974
# Epoch 43/1000
# 8/8 [==============================] - 0s 60ms/step - loss: 0.6024 - categorical_accuracy: 0.7500
# Epoch 44/1000
# 8/8 [==============================] - 0s 60ms/step - loss: 0.5023 - categorical_accuracy: 0.7939
# Epoch 45/1000
# 8/8 [==============================] - 0s 48ms/step - loss: 0.4680 - categorical_accuracy: 0.8202
# Epoch 46/1000
# 8/8 [==============================] - 0s 48ms/step - loss: 0.4564 - categorical_accuracy: 0.8026
# Epoch 47/1000
# 8/8 [==============================] - 0s 49ms/step - loss: 0.4203 - categorical_accuracy: 0.8596
# Epoch 48/1000
# 8/8 [==============================] - 0s 48ms/step - loss: 0.3180 - categorical_accuracy: 0.8816
# Epoch 49/1000
# 8/8 [==============================] - 0s 49ms/step - loss: 0.3559 - categorical_accuracy: 0.8640
# Epoch 50/1000
# 8/8 [==============================] - 1s 77ms/step - loss: 0.2481 - categorical_accuracy: 0.9123
# Epoch 51/1000
# 8/8 [==============================] - 1s 77ms/step - loss: 0.3321 - categorical_accuracy: 0.8991
# Epoch 52/1000
# 8/8 [==============================] - 1s 77ms/step - loss: 0.3316 - categorical_accuracy: 0.9079
# Epoch 53/1000
# 8/8 [==============================] - 1s 76ms/step - loss: 0.2775 - categorical_accuracy: 0.8816
# Epoch 54/1000
# 8/8 [==============================] - 1s 76ms/step - loss: 0.2825 - categorical_accuracy: 0.8640
# Epoch 55/1000
# 8/8 [==============================] - 1s 76ms/step - loss: 0.2446 - categorical_accuracy: 0.9123
# Epoch 56/1000
# 8/8 [==============================] - 1s 76ms/step - loss: 0.3245 - categorical_accuracy: 0.8640
# Epoch 57/1000
# 8/8 [==============================] - 1s 76ms/step - loss: 0.2024 - categorical_accuracy: 0.9474
# Epoch 58/1000
# 8/8 [==============================] - 1s 76ms/step - loss: 0.3644 - categorical_accuracy: 0.8553
# Epoch 59/1000
# 8/8 [==============================] - 1s 76ms/step - loss: 0.3099 - categorical_accuracy: 0.9167
# Epoch 60/1000
# 8/8 [==============================] - 1s 76ms/step - loss: 0.2962 - categorical_accuracy: 0.8904
# Epoch 61/1000
# 8/8 [==============================] - 1s 76ms/step - loss: 0.5847 - categorical_accuracy: 0.8114
# Epoch 62/1000
# 8/8 [==============================] - 1s 74ms/step - loss: 0.5554 - categorical_accuracy: 0.7675
# Epoch 63/1000
# 8/8 [==============================] - 0s 46ms/step - loss: 0.5060 - categorical_accuracy: 0.8289
# Epoch 64/1000
# 8/8 [==============================] - 0s 46ms/step - loss: 0.4401 - categorical_accuracy: 0.8772
# Epoch 65/1000
# 8/8 [==============================] - 0s 49ms/step - loss: 0.3842 - categorical_accuracy: 0.8553
# Epoch 66/1000
# 8/8 [==============================] - 0s 51ms/step - loss: 0.4604 - categorical_accuracy: 0.8114
# Epoch 67/1000
# 8/8 [==============================] - 0s 50ms/step - loss: 0.4489 - categorical_accuracy: 0.8684
# Epoch 68/1000
# 8/8 [==============================] - 1s 109ms/step - loss: 0.4475 - categorical_accuracy: 0.8684
# Epoch 69/1000
# 8/8 [==============================] - 1s 102ms/step - loss: 0.5189 - categorical_accuracy: 0.8246
# Epoch 70/1000
# 8/8 [==============================] - 0s 53ms/step - loss: 0.4430 - categorical_accuracy: 0.8289
# Epoch 71/1000
# 8/8 [==============================] - 0s 62ms/step - loss: 0.3443 - categorical_accuracy: 0.8684
# Epoch 72/1000
# 8/8 [==============================] - 0s 61ms/step - loss: 0.2332 - categorical_accuracy: 0.9167
# Epoch 73/1000
# 8/8 [==============================] - 0s 61ms/step - loss: 0.3530 - categorical_accuracy: 0.9342
# Epoch 74/1000
# 8/8 [==============================] - 1s 77ms/step - loss: 1.4050 - categorical_accuracy: 0.5789
# Epoch 75/1000
# 8/8 [==============================] - 0s 56ms/step - loss: 1.8220 - categorical_accuracy: 0.4430
# Epoch 76/1000
# 8/8 [==============================] - 0s 52ms/step - loss: 1.3347 - categorical_accuracy: 0.4298
# Epoch 77/1000
# 8/8 [==============================] - 0s 53ms/step - loss: 1.3597 - categorical_accuracy: 0.4298
# Epoch 78/1000
# 8/8 [==============================] - 0s 56ms/step - loss: 1.0288 - categorical_accuracy: 0.7325
# Epoch 79/1000
# 8/8 [==============================] - 1s 64ms/step - loss: 1.0491 - categorical_accuracy: 0.6053
# Epoch 80/1000
# 8/8 [==============================] - 1s 65ms/step - loss: 0.8730 - categorical_accuracy: 0.6842
# Epoch 81/1000
# 8/8 [==============================] - 1s 63ms/step - loss: 0.7441 - categorical_accuracy: 0.7061
# Epoch 82/1000
# 8/8 [==============================] - 1s 63ms/step - loss: 0.5578 - categorical_accuracy: 0.8421
# Epoch 83/1000
# 8/8 [==============================] - 1s 77ms/step - loss: 0.5999 - categorical_accuracy: 0.8333
# Epoch 84/1000
# 8/8 [==============================] - 1s 77ms/step - loss: 0.4738 - categorical_accuracy: 0.8553
# Epoch 85/1000
# 8/8 [==============================] - 1s 77ms/step - loss: 0.3922 - categorical_accuracy: 0.8684
# Epoch 86/1000
# 8/8 [==============================] - 1s 76ms/step - loss: 0.4297 - categorical_accuracy: 0.8465
# Epoch 87/1000
# 8/8 [==============================] - 1s 76ms/step - loss: 0.3815 - categorical_accuracy: 0.8596
# Epoch 88/1000
# 8/8 [==============================] - 1s 77ms/step - loss: 0.2940 - categorical_accuracy: 0.8816
# Epoch 89/1000
# 8/8 [==============================] - 1s 77ms/step - loss: 0.3313 - categorical_accuracy: 0.8904
# Epoch 90/1000
# 8/8 [==============================] - 1s 78ms/step - loss: 0.2746 - categorical_accuracy: 0.8991
# Epoch 91/1000
# 8/8 [==============================] - 1s 77ms/step - loss: 0.1571 - categorical_accuracy: 0.9561
# Epoch 92/1000
# 8/8 [==============================] - 1s 76ms/step - loss: 0.1673 - categorical_accuracy: 0.9386
# Epoch 93/1000
# 8/8 [==============================] - 0s 57ms/step - loss: 0.1396 - categorical_accuracy: 0.9430
# Epoch 94/1000
# 8/8 [==============================] - 1s 75ms/step - loss: 0.0840 - categorical_accuracy: 0.9693
# Epoch 95/1000
# 8/8 [==============================] - 0s 47ms/step - loss: 0.0802 - categorical_accuracy: 0.9868
# Epoch 96/1000
# 8/8 [==============================] - 0s 41ms/step - loss: 0.0844 - categorical_accuracy: 0.9649
# Epoch 97/1000
# 8/8 [==============================] - 0s 44ms/step - loss: 0.8061 - categorical_accuracy: 0.8728
# Epoch 98/1000
# 8/8 [==============================] - 1s 102ms/step - loss: 0.6524 - categorical_accuracy: 0.7456
# Epoch 99/1000
# 8/8 [==============================] - 1s 105ms/step - loss: 1.1086 - categorical_accuracy: 0.5833
# Epoch 100/1000
# 8/8 [==============================] - 1s 103ms/step - loss: 0.6885 - categorical_accuracy: 0.7500
# Epoch 101/1000
# 8/8 [==============================] - 1s 101ms/step - loss: 0.5654 - categorical_accuracy: 0.8114
# Epoch 102/1000
# 8/8 [==============================] - 1s 90ms/step - loss: 0.4166 - categorical_accuracy: 0.8816
# Epoch 103/1000
# 8/8 [==============================] - 1s 89ms/step - loss: 0.3649 - categorical_accuracy: 0.8904
# Epoch 104/1000
# 8/8 [==============================] - 1s 92ms/step - loss: 0.3467 - categorical_accuracy: 0.8860
# Epoch 105/1000
# 8/8 [==============================] - 1s 89ms/step - loss: 0.2775 - categorical_accuracy: 0.9211
# Epoch 106/1000
# 8/8 [==============================] - 1s 107ms/step - loss: 0.2382 - categorical_accuracy: 0.9342
# Epoch 107/1000
# 8/8 [==============================] - 1s 98ms/step - loss: 0.2190 - categorical_accuracy: 0.8991
# Epoch 108/1000
# 8/8 [==============================] - 1s 93ms/step - loss: 0.2397 - categorical_accuracy: 0.9079
# Epoch 109/1000
# 8/8 [==============================] - 1s 97ms/step - loss: 0.1683 - categorical_accuracy: 0.9561
# Epoch 110/1000
# 8/8 [==============================] - 1s 98ms/step - loss: 0.1516 - categorical_accuracy: 0.9518
# Epoch 111/1000
# 8/8 [==============================] - 1s 98ms/step - loss: 0.7375 - categorical_accuracy: 0.7719
# Epoch 112/1000
# 8/8 [==============================] - 1s 100ms/step - loss: 0.5342 - categorical_accuracy: 0.7807
# Epoch 113/1000
# 8/8 [==============================] - 1s 98ms/step - loss: 0.4858 - categorical_accuracy: 0.8070
# Epoch 114/1000
# 8/8 [==============================] - 1s 99ms/step - loss: 0.2946 - categorical_accuracy: 0.9079
# Epoch 115/1000
# 8/8 [==============================] - 1s 99ms/step - loss: 0.2311 - categorical_accuracy: 0.9167
# Epoch 116/1000
# 8/8 [==============================] - 1s 89ms/step - loss: 0.1795 - categorical_accuracy: 0.9518
# Epoch 117/1000
# 8/8 [==============================] - 0s 47ms/step - loss: 0.1503 - categorical_accuracy: 0.9474
# Epoch 118/1000
# 8/8 [==============================] - 1s 109ms/step - loss: 0.1047 - categorical_accuracy: 0.9693
# Epoch 119/1000
# 8/8 [==============================] - 1s 102ms/step - loss: 0.0759 - categorical_accuracy: 0.9868
# Epoch 120/1000
# 8/8 [==============================] - 1s 101ms/step - loss: 0.0804 - categorical_accuracy: 0.9693
# Epoch 121/1000
# 8/8 [==============================] - 1s 60ms/step - loss: 0.0733 - categorical_accuracy: 0.9737
# Epoch 122/1000
# 8/8 [==============================] - 0s 58ms/step - loss: 0.2455 - categorical_accuracy: 0.9430
# Epoch 123/1000
# 8/8 [==============================] - 0s 53ms/step - loss: 0.5821 - categorical_accuracy: 0.8114
# Epoch 124/1000
# 8/8 [==============================] - 0s 49ms/step - loss: 1.3123 - categorical_accuracy: 0.5614
# Epoch 125/1000
# 8/8 [==============================] - 0s 51ms/step - loss: 1.0391 - categorical_accuracy: 0.5877
# Epoch 126/1000
# 8/8 [==============================] - 0s 52ms/step - loss: 0.9725 - categorical_accuracy: 0.6623
# Epoch 127/1000
# 8/8 [==============================] - 1s 69ms/step - loss: 0.9014 - categorical_accuracy: 0.6798
# Epoch 128/1000
# 8/8 [==============================] - 0s 61ms/step - loss: 0.8031 - categorical_accuracy: 0.7500
# Epoch 129/1000
# 8/8 [==============================] - 0s 61ms/step - loss: 0.7436 - categorical_accuracy: 0.7325
# Epoch 130/1000
# 8/8 [==============================] - 1s 68ms/step - loss: 0.6702 - categorical_accuracy: 0.7544
# Epoch 131/1000
# 8/8 [==============================] - 0s 60ms/step - loss: 0.5907 - categorical_accuracy: 0.7939
# Epoch 132/1000
# 8/8 [==============================] - 0s 61ms/step - loss: 0.5207 - categorical_accuracy: 0.8158
# Epoch 133/1000
# 8/8 [==============================] - 0s 60ms/step - loss: 0.4657 - categorical_accuracy: 0.8202
# Epoch 134/1000
# 8/8 [==============================] - 0s 60ms/step - loss: 0.4069 - categorical_accuracy: 0.8377
# Epoch 135/1000
# 8/8 [==============================] - 1s 72ms/step - loss: 0.3477 - categorical_accuracy: 0.8596
# Epoch 136/1000
# 8/8 [==============================] - 1s 71ms/step - loss: 0.2534 - categorical_accuracy: 0.9298
# Epoch 137/1000
# 8/8 [==============================] - 1s 71ms/step - loss: 0.2125 - categorical_accuracy: 0.9386
# Epoch 138/1000
# 8/8 [==============================] - 1s 68ms/step - loss: 0.1332 - categorical_accuracy: 0.9693
# Epoch 139/1000
# 8/8 [==============================] - 1s 69ms/step - loss: 0.0902 - categorical_accuracy: 0.9737
# Epoch 140/1000
# 8/8 [==============================] - 1s 69ms/step - loss: 0.0622 - categorical_accuracy: 0.9868
# Epoch 141/1000
# 8/8 [==============================] - 1s 106ms/step - loss: 0.0559 - categorical_accuracy: 0.9868
# Epoch 142/1000
# 8/8 [==============================] - 1s 91ms/step - loss: 0.0563 - categorical_accuracy: 0.9825
# Epoch 143/1000
# 8/8 [==============================] - 1s 99ms/step - loss: 0.1353 - categorical_accuracy: 0.9561
# Epoch 144/1000
# 8/8 [==============================] - 1s 91ms/step - loss: 0.1294 - categorical_accuracy: 0.9430
# Epoch 145/1000
# 8/8 [==============================] - 1s 58ms/step - loss: 0.1521 - categorical_accuracy: 0.9430
# Epoch 146/1000
# 8/8 [==============================] - 0s 44ms/step - loss: 0.0918 - categorical_accuracy: 0.9912
# Epoch 147/1000
# 8/8 [==============================] - 0s 59ms/step - loss: 0.0719 - categorical_accuracy: 0.9825
# Epoch 148/1000
# 8/8 [==============================] - 1s 68ms/step - loss: 0.0493 - categorical_accuracy: 0.9912
# Epoch 149/1000
# 8/8 [==============================] - 0s 62ms/step - loss: 0.0387 - categorical_accuracy: 0.9912
# Epoch 150/1000
# 8/8 [==============================] - 0s 62ms/step - loss: 0.0301 - categorical_accuracy: 0.9912
# Epoch 151/1000
# 8/8 [==============================] - 0s 52ms/step - loss: 0.0216 - categorical_accuracy: 1.0000
# Epoch 152/1000
# 8/8 [==============================] - 0s 49ms/step - loss: 0.0159 - categorical_accuracy: 1.0000
# Epoch 153/1000
# 8/8 [==============================] - 1s 77ms/step - loss: 0.0392 - categorical_accuracy: 0.9912
# Epoch 154/1000
# 8/8 [==============================] - 1s 76ms/step - loss: 0.0138 - categorical_accuracy: 1.0000
# Epoch 155/1000
# 8/8 [==============================] - 1s 76ms/step - loss: 0.0151 - categorical_accuracy: 1.0000
# Epoch 156/1000
# 8/8 [==============================] - 1s 78ms/step - loss: 0.1924 - categorical_accuracy: 0.9693
# Epoch 157/1000
# 8/8 [==============================] - 1s 75ms/step - loss: 0.1122 - categorical_accuracy: 0.9693
# Epoch 158/1000
# 8/8 [==============================] - 1s 73ms/step - loss: 0.7312 - categorical_accuracy: 0.8289
# Epoch 159/1000
# 8/8 [==============================] - 0s 58ms/step - loss: 0.3893 - categorical_accuracy: 0.8377
# Epoch 160/1000
# 8/8 [==============================] - 1s 97ms/step - loss: 0.2885 - categorical_accuracy: 0.9254
# Epoch 161/1000
# 8/8 [==============================] - 1s 95ms/step - loss: 0.2022 - categorical_accuracy: 0.9561
# Epoch 162/1000
# 8/8 [==============================] - 1s 93ms/step - loss: 0.1374 - categorical_accuracy: 0.9737
# Epoch 163/1000
# 8/8 [==============================] - 1s 102ms/step - loss: 0.0854 - categorical_accuracy: 0.9781
# Epoch 164/1000
# 8/8 [==============================] - 1s 99ms/step - loss: 0.0612 - categorical_accuracy: 0.9868
# Epoch 165/1000
# 8/8 [==============================] - 1s 98ms/step - loss: 0.0437 - categorical_accuracy: 0.9956
# Epoch 166/1000
# 8/8 [==============================] - 0s 48ms/step - loss: 0.0298 - categorical_accuracy: 0.9956
# Epoch 167/1000
# 8/8 [==============================] - 0s 47ms/step - loss: 0.0235 - categorical_accuracy: 0.9956
# Epoch 168/1000
# 8/8 [==============================] - 1s 61ms/step - loss: 0.0181 - categorical_accuracy: 0.9956
# Epoch 169/1000
# 8/8 [==============================] - 0s 47ms/step - loss: 0.0147 - categorical_accuracy: 0.9956
# Epoch 170/1000
# 8/8 [==============================] - 1s 98ms/step - loss: 0.3631 - categorical_accuracy: 0.9605
# Epoch 171/1000
# 8/8 [==============================] - 1s 95ms/step - loss: 1.1679 - categorical_accuracy: 0.7456
# Epoch 172/1000
# 8/8 [==============================] - 1s 87ms/step - loss: 0.8388 - categorical_accuracy: 0.6579
# Epoch 173/1000
# 8/8 [==============================] - 0s 54ms/step - loss: 0.8090 - categorical_accuracy: 0.6974
# Epoch 174/1000
# 8/8 [==============================] - 0s 56ms/step - loss: 0.7464 - categorical_accuracy: 0.7149
# Epoch 175/1000
# 8/8 [==============================] - 0s 52ms/step - loss: 0.6684 - categorical_accuracy: 0.7237
# Epoch 176/1000
# 8/8 [==============================] - 0s 53ms/step - loss: 0.5526 - categorical_accuracy: 0.7939
# Epoch 177/1000
# 8/8 [==============================] - 0s 48ms/step - loss: 0.4303 - categorical_accuracy: 0.8816
# Epoch 178/1000
# 8/8 [==============================] - 1s 77ms/step - loss: 0.3300 - categorical_accuracy: 0.9123
# Epoch 179/1000
# 8/8 [==============================] - 0s 49ms/step - loss: 0.3039 - categorical_accuracy: 0.9254
# Epoch 180/1000
# 8/8 [==============================] - 0s 49ms/step - loss: 0.3229 - categorical_accuracy: 0.8596
# Epoch 181/1000
# 8/8 [==============================] - 0s 51ms/step - loss: 0.2326 - categorical_accuracy: 0.9035
# Epoch 182/1000
# 8/8 [==============================] - 0s 53ms/step - loss: 0.2160 - categorical_accuracy: 0.9342
# Epoch 183/1000
# 8/8 [==============================] - 0s 58ms/step - loss: 0.1815 - categorical_accuracy: 0.9430
# Epoch 184/1000
# 8/8 [==============================] - 1s 65ms/step - loss: 0.1383 - categorical_accuracy: 0.9649
# Epoch 185/1000
# 8/8 [==============================] - 0s 60ms/step - loss: 0.1201 - categorical_accuracy: 0.9649
# Epoch 186/1000
# 8/8 [==============================] - 0s 62ms/step - loss: 0.1081 - categorical_accuracy: 0.9693
# Epoch 187/1000
# 8/8 [==============================] - 0s 61ms/step - loss: 0.1016 - categorical_accuracy: 0.9649
# Epoch 188/1000
# 8/8 [==============================] - 0s 62ms/step - loss: 0.0950 - categorical_accuracy: 0.9693
# Epoch 189/1000
# 8/8 [==============================] - 1s 62ms/step - loss: 9.2416 - categorical_accuracy: 0.7982
# Epoch 190/1000
# 8/8 [==============================] - 0s 62ms/step - loss: 0.9694 - categorical_accuracy: 0.6447
# Epoch 191/1000
# 8/8 [==============================] - 0s 47ms/step - loss: 0.7813 - categorical_accuracy: 0.6798
# Epoch 192/1000
# 8/8 [==============================] - 0s 49ms/step - loss: 0.6574 - categorical_accuracy: 0.7807
# Epoch 193/1000
# 8/8 [==============================] - 0s 51ms/step - loss: 0.5210 - categorical_accuracy: 0.8333
# Epoch 194/1000
# 8/8 [==============================] - 0s 58ms/step - loss: 0.4520 - categorical_accuracy: 0.8289
# Epoch 195/1000
# 8/8 [==============================] - 0s 58ms/step - loss: 0.3728 - categorical_accuracy: 0.8684
# Epoch 196/1000
# 8/8 [==============================] - 0s 58ms/step - loss: 0.2948 - categorical_accuracy: 0.9254
# Epoch 197/1000
# 8/8 [==============================] - 1s 77ms/step - loss: 0.2571 - categorical_accuracy: 0.9167
# Epoch 198/1000
# 8/8 [==============================] - 1s 76ms/step - loss: 0.2265 - categorical_accuracy: 0.8947
# Epoch 199/1000
# 8/8 [==============================] - 1s 76ms/step - loss: 0.1656 - categorical_accuracy: 0.9518
# Epoch 200/1000
# 8/8 [==============================] - 1s 75ms/step - loss: 0.1298 - categorical_accuracy: 0.9693
# Epoch 201/1000
# 8/8 [==============================] - 1s 76ms/step - loss: 0.2941 - categorical_accuracy: 0.9386
# Epoch 202/1000
# 8/8 [==============================] - 1s 76ms/step - loss: 0.1667 - categorical_accuracy: 0.9474
# Epoch 203/1000
# 8/8 [==============================] - 1s 76ms/step - loss: 0.2961 - categorical_accuracy: 0.9474
# Epoch 204/1000
# 8/8 [==============================] - 1s 78ms/step - loss: 1.2439 - categorical_accuracy: 0.7807
# Epoch 205/1000
# 8/8 [==============================] - 1s 73ms/step - loss: 0.7072 - categorical_accuracy: 0.7456
# Epoch 206/1000
# 8/8 [==============================] - 1s 99ms/step - loss: 4.4561 - categorical_accuracy: 0.6272
# Epoch 207/1000
# 8/8 [==============================] - 1s 90ms/step - loss: 1.0847 - categorical_accuracy: 0.5833
# Epoch 208/1000
# 8/8 [==============================] - 0s 49ms/step - loss: 1.0473 - categorical_accuracy: 0.6404
# Epoch 209/1000
# 8/8 [==============================] - 0s 43ms/step - loss: 0.8365 - categorical_accuracy: 0.7281
# Epoch 210/1000
# 8/8 [==============================] - 0s 51ms/step - loss: 0.6970 - categorical_accuracy: 0.7895
# Epoch 211/1000
# 8/8 [==============================] - 0s 49ms/step - loss: 0.5510 - categorical_accuracy: 0.8421
# Epoch 212/1000
# 8/8 [==============================] - 0s 47ms/step - loss: 0.4862 - categorical_accuracy: 0.8289
# Epoch 213/1000
# 8/8 [==============================] - 0s 49ms/step - loss: 0.3450 - categorical_accuracy: 0.8991
# Epoch 214/1000
# 8/8 [==============================] - 1s 83ms/step - loss: 0.4648 - categorical_accuracy: 0.8816
# Epoch 215/1000
# 8/8 [==============================] - 1s 82ms/step - loss: 0.3552 - categorical_accuracy: 0.9079
# Epoch 216/1000
# 8/8 [==============================] - 1s 82ms/step - loss: 0.3257 - categorical_accuracy: 0.8991
# Epoch 217/1000
# 8/8 [==============================] - 1s 82ms/step - loss: 0.2952 - categorical_accuracy: 0.9123
# Epoch 218/1000
# 8/8 [==============================] - 1s 82ms/step - loss: 0.2473 - categorical_accuracy: 0.9298
# Epoch 219/1000
# 8/8 [==============================] - 1s 83ms/step - loss: 0.2066 - categorical_accuracy: 0.9386
# Epoch 220/1000
# 8/8 [==============================] - 1s 82ms/step - loss: 0.1864 - categorical_accuracy: 0.9518
# Epoch 221/1000
# 8/8 [==============================] - 1s 60ms/step - loss: 0.1483 - categorical_accuracy: 0.9693
# Epoch 222/1000
# 8/8 [==============================] - 0s 51ms/step - loss: 0.4963 - categorical_accuracy: 0.9649
# Epoch 223/1000
# 8/8 [==============================] - 0s 49ms/step - loss: 4.7604 - categorical_accuracy: 0.5702
# Epoch 224/1000
# 8/8 [==============================] - 1s 64ms/step - loss: 1.4179 - categorical_accuracy: 0.5307
# Epoch 225/1000
# 8/8 [==============================] - 0s 48ms/step - loss: 1.5417 - categorical_accuracy: 0.4649
# Epoch 226/1000
# 8/8 [==============================] - 1s 63ms/step - loss: 1.3970 - categorical_accuracy: 0.4912
# Epoch 227/1000
# 8/8 [==============================] - 0s 59ms/step - loss: 1.1799 - categorical_accuracy: 0.6140
# Epoch 228/1000
# 8/8 [==============================] - 0s 61ms/step - loss: 1.0492 - categorical_accuracy: 0.6272
# Epoch 229/1000
# 8/8 [==============================] - 0s 61ms/step - loss: 0.9023 - categorical_accuracy: 0.6754
# Epoch 230/1000
# 8/8 [==============================] - 1s 72ms/step - loss: 0.7965 - categorical_accuracy: 0.6886
# Epoch 231/1000
# 8/8 [==============================] - 1s 72ms/step - loss: 0.6861 - categorical_accuracy: 0.7193
# Epoch 232/1000
# 8/8 [==============================] - 1s 77ms/step - loss: 0.8100 - categorical_accuracy: 0.7851
# Epoch 233/1000
# 8/8 [==============================] - 1s 76ms/step - loss: 0.6915 - categorical_accuracy: 0.7895
# Epoch 234/1000
# 8/8 [==============================] - 1s 76ms/step - loss: 0.5592 - categorical_accuracy: 0.8509
# Epoch 235/1000
# 8/8 [==============================] - 1s 77ms/step - loss: 0.4835 - categorical_accuracy: 0.8114
# Epoch 236/1000
# 8/8 [==============================] - 1s 75ms/step - loss: 0.4056 - categorical_accuracy: 0.8684
# Epoch 237/1000
# 8/8 [==============================] - 1s 76ms/step - loss: 0.4658 - categorical_accuracy: 0.8421
# Epoch 238/1000
# 8/8 [==============================] - 1s 76ms/step - loss: 0.4758 - categorical_accuracy: 0.8202
# Epoch 239/1000
# 8/8 [==============================] - 1s 76ms/step - loss: 0.4506 - categorical_accuracy: 0.8377
# Epoch 240/1000
# 8/8 [==============================] - 1s 78ms/step - loss: 0.3425 - categorical_accuracy: 0.9035
# Epoch 241/1000
# 8/8 [==============================] - 1s 76ms/step - loss: 0.2974 - categorical_accuracy: 0.8816
# Epoch 242/1000
# 8/8 [==============================] - 1s 75ms/step - loss: 0.2692 - categorical_accuracy: 0.8991
# Epoch 243/1000
# 8/8 [==============================] - 1s 76ms/step - loss: 0.1909 - categorical_accuracy: 0.9342
# Epoch 244/1000
# 8/8 [==============================] - 1s 75ms/step - loss: 0.1485 - categorical_accuracy: 0.9605
# Epoch 245/1000
# 8/8 [==============================] - 1s 75ms/step - loss: 0.6523 - categorical_accuracy: 0.8553
# Epoch 246/1000
# 8/8 [==============================] - 1s 75ms/step - loss: 0.5264 - categorical_accuracy: 0.8070
# Epoch 247/1000
# 8/8 [==============================] - 1s 76ms/step - loss: 0.4760 - categorical_accuracy: 0.8202
# Epoch 248/1000
# 8/8 [==============================] - 1s 76ms/step - loss: 0.3490 - categorical_accuracy: 0.8991
# Epoch 249/1000
# 8/8 [==============================] - 1s 76ms/step - loss: 0.2445 - categorical_accuracy: 0.9342
# Epoch 250/1000
# 8/8 [==============================] - 1s 76ms/step - loss: 0.2018 - categorical_accuracy: 0.9386
# Epoch 251/1000
# 8/8 [==============================] - 1s 75ms/step - loss: 0.1876 - categorical_accuracy: 0.9430
# Epoch 252/1000
# 8/8 [==============================] - 1s 76ms/step - loss: 0.2049 - categorical_accuracy: 0.9211
# Epoch 253/1000
# 8/8 [==============================] - 1s 75ms/step - loss: 0.1271 - categorical_accuracy: 0.9693
# Epoch 254/1000
# 8/8 [==============================] - 1s 76ms/step - loss: 0.1190 - categorical_accuracy: 0.9649
# Epoch 255/1000
# 8/8 [==============================] - 1s 76ms/step - loss: 0.0789 - categorical_accuracy: 0.9781
# Epoch 256/1000
# 8/8 [==============================] - 1s 76ms/step - loss: 0.0551 - categorical_accuracy: 0.9868
# Epoch 257/1000
# 8/8 [==============================] - 1s 76ms/step - loss: 0.0414 - categorical_accuracy: 0.9912
# Epoch 258/1000
# 8/8 [==============================] - 1s 76ms/step - loss: 0.0296 - categorical_accuracy: 0.9912
# Epoch 259/1000
# 8/8 [==============================] - 1s 76ms/step - loss: 0.0237 - categorical_accuracy: 0.9956
# Epoch 260/1000
# 8/8 [==============================] - 1s 76ms/step - loss: 0.0199 - categorical_accuracy: 1.0000
# Epoch 261/1000
# 8/8 [==============================] - 1s 76ms/step - loss: 0.0291 - categorical_accuracy: 0.9912
# Epoch 262/1000
# 8/8 [==============================] - 1s 76ms/step - loss: 2.1745 - categorical_accuracy: 0.7588
# Epoch 263/1000
# 8/8 [==============================] - 1s 76ms/step - loss: 1.3460 - categorical_accuracy: 0.6140
# Epoch 264/1000
# 8/8 [==============================] - 1s 76ms/step - loss: 0.8480 - categorical_accuracy: 0.6930
# Epoch 265/1000
# 8/8 [==============================] - 1s 76ms/step - loss: 0.7094 - categorical_accuracy: 0.7237
# Epoch 266/1000
# 8/8 [==============================] - 1s 75ms/step - loss: 0.6648 - categorical_accuracy: 0.7807
# Epoch 267/1000
# 8/8 [==============================] - 1s 75ms/step - loss: 0.5908 - categorical_accuracy: 0.8202
# Epoch 268/1000
# 8/8 [==============================] - 1s 76ms/step - loss: 0.5109 - categorical_accuracy: 0.8377
# Epoch 269/1000
# 8/8 [==============================] - 1s 76ms/step - loss: 0.4377 - categorical_accuracy: 0.8816
# Epoch 270/1000
# 8/8 [==============================] - 1s 69ms/step - loss: 0.3728 - categorical_accuracy: 0.9211
# Epoch 271/1000
# 8/8 [==============================] - 1s 74ms/step - loss: 0.8090 - categorical_accuracy: 0.8202
# Epoch 272/1000
# 8/8 [==============================] - 1s 74ms/step - loss: 0.6106 - categorical_accuracy: 0.7719
# Epoch 273/1000
# 8/8 [==============================] - 1s 74ms/step - loss: 0.5041 - categorical_accuracy: 0.8114
# Epoch 274/1000
# 8/8 [==============================] - 1s 95ms/step - loss: 0.4643 - categorical_accuracy: 0.8596
# Epoch 275/1000
# 8/8 [==============================] - 1s 95ms/step - loss: 0.4014 - categorical_accuracy: 0.8860
# Epoch 276/1000
# 8/8 [==============================] - 1s 96ms/step - loss: 0.3674 - categorical_accuracy: 0.8860
# Epoch 277/1000
# 8/8 [==============================] - 1s 95ms/step - loss: 0.3446 - categorical_accuracy: 0.8904
# Epoch 278/1000
# 8/8 [==============================] - 1s 94ms/step - loss: 0.3020 - categorical_accuracy: 0.9079
# Epoch 279/1000
# 8/8 [==============================] - 1s 94ms/step - loss: 0.2832 - categorical_accuracy: 0.9035
# Epoch 280/1000
# 8/8 [==============================] - 1s 94ms/step - loss: 0.2422 - categorical_accuracy: 0.9211
# Epoch 281/1000
# 8/8 [==============================] - 1s 95ms/step - loss: 0.2272 - categorical_accuracy: 0.9167
# Epoch 282/1000
# 8/8 [==============================] - 1s 93ms/step - loss: 0.2046 - categorical_accuracy: 0.9167
# Epoch 283/1000
# 8/8 [==============================] - 1s 93ms/step - loss: 0.1775 - categorical_accuracy: 0.9342
# Epoch 284/1000
# 8/8 [==============================] - 1s 91ms/step - loss: 0.1625 - categorical_accuracy: 0.9386
# Epoch 285/1000
# 8/8 [==============================] - 1s 87ms/step - loss: 0.1559 - categorical_accuracy: 0.9430
# Epoch 286/1000
# 8/8 [==============================] - 1s 88ms/step - loss: 0.1607 - categorical_accuracy: 0.9430
# Epoch 287/1000
# 8/8 [==============================] - 1s 76ms/step - loss: 0.1336 - categorical_accuracy: 0.9474
# Epoch 288/1000
# 8/8 [==============================] - 0s 59ms/step - loss: 0.1211 - categorical_accuracy: 0.9561
# Epoch 289/1000
# 8/8 [==============================] - 0s 61ms/step - loss: 0.1121 - categorical_accuracy: 0.9605
# Epoch 290/1000
# 8/8 [==============================] - 0s 61ms/step - loss: 0.1041 - categorical_accuracy: 0.9693
# Epoch 291/1000
# 8/8 [==============================] - 0s 60ms/step - loss: 0.0969 - categorical_accuracy: 0.9693
# Epoch 292/1000
# 8/8 [==============================] - 0s 58ms/step - loss: 0.0848 - categorical_accuracy: 0.9693
# Epoch 293/1000
# 8/8 [==============================] - 1s 77ms/step - loss: 0.0765 - categorical_accuracy: 0.9781
# Epoch 294/1000
# 8/8 [==============================] - 1s 67ms/step - loss: 0.0698 - categorical_accuracy: 0.9825
# Epoch 295/1000
# 8/8 [==============================] - 0s 46ms/step - loss: 0.0660 - categorical_accuracy: 0.9781
# Epoch 296/1000
# 8/8 [==============================] - 1s 106ms/step - loss: 0.0628 - categorical_accuracy: 0.9825
# Epoch 297/1000
# 8/8 [==============================] - 1s 97ms/step - loss: 0.1158 - categorical_accuracy: 0.9649
# Epoch 298/1000
# 8/8 [==============================] - 1s 98ms/step - loss: 0.3151 - categorical_accuracy: 0.9167
# Epoch 299/1000
# 8/8 [==============================] - 1s 100ms/step - loss: 0.1718 - categorical_accuracy: 0.9342
# Epoch 300/1000
# 8/8 [==============================] - 1s 101ms/step - loss: 0.1925 - categorical_accuracy: 0.9254
# Epoch 301/1000
# 8/8 [==============================] - 1s 99ms/step - loss: 0.1255 - categorical_accuracy: 0.9474
# Epoch 302/1000
# 8/8 [==============================] - 1s 98ms/step - loss: 0.1263 - categorical_accuracy: 0.9561
# Epoch 303/1000
# 8/8 [==============================] - 1s 89ms/step - loss: 0.0748 - categorical_accuracy: 0.9825
# Epoch 304/1000
# 8/8 [==============================] - 1s 89ms/step - loss: 0.0761 - categorical_accuracy: 0.9825
# Epoch 305/1000
# 8/8 [==============================] - 1s 88ms/step - loss: 0.0690 - categorical_accuracy: 0.9825
# Epoch 306/1000
# 8/8 [==============================] - 1s 87ms/step - loss: 0.0556 - categorical_accuracy: 0.9912
# Epoch 307/1000
# 8/8 [==============================] - 1s 91ms/step - loss: 0.0473 - categorical_accuracy: 0.9868
# Epoch 308/1000
# 8/8 [==============================] - 1s 90ms/step - loss: 0.0442 - categorical_accuracy: 0.9912
# Epoch 309/1000
# 8/8 [==============================] - 1s 91ms/step - loss: 0.0401 - categorical_accuracy: 0.9868
# Epoch 310/1000
# 8/8 [==============================] - 1s 88ms/step - loss: 0.0379 - categorical_accuracy: 0.9912
# Epoch 311/1000
# 8/8 [==============================] - 1s 89ms/step - loss: 0.0328 - categorical_accuracy: 0.9912
# Epoch 312/1000
# 8/8 [==============================] - 1s 91ms/step - loss: 0.0278 - categorical_accuracy: 0.9956
# Epoch 313/1000
# 8/8 [==============================] - 1s 92ms/step - loss: 0.0258 - categorical_accuracy: 0.9956
# Epoch 314/1000
# 8/8 [==============================] - 0s 50ms/step - loss: 0.0232 - categorical_accuracy: 0.9956
# Epoch 315/1000
# 8/8 [==============================] - 1s 74ms/step - loss: 0.0208 - categorical_accuracy: 1.0000
# Epoch 316/1000
# 8/8 [==============================] - 1s 76ms/step - loss: 0.0209 - categorical_accuracy: 0.9956
# Epoch 317/1000
# 8/8 [==============================] - 1s 73ms/step - loss: 0.0330 - categorical_accuracy: 0.9868
# Epoch 318/1000
# 8/8 [==============================] - 1s 94ms/step - loss: 0.0233 - categorical_accuracy: 1.0000
# Epoch 319/1000
# 8/8 [==============================] - 1s 90ms/step - loss: 0.0239 - categorical_accuracy: 0.9912
# Epoch 320/1000
# 8/8 [==============================] - 1s 90ms/step - loss: 0.0167 - categorical_accuracy: 0.9956
# Epoch 321/1000
# 8/8 [==============================] - 1s 91ms/step - loss: 0.0151 - categorical_accuracy: 0.9956
# Epoch 322/1000
# 8/8 [==============================] - 1s 98ms/step - loss: 0.0128 - categorical_accuracy: 0.9956
# Epoch 323/1000
# 8/8 [==============================] - 1s 101ms/step - loss: 0.0135 - categorical_accuracy: 1.0000
# Epoch 324/1000
# 8/8 [==============================] - 1s 99ms/step - loss: 0.0110 - categorical_accuracy: 0.9956
# Epoch 325/1000
# 8/8 [==============================] - 1s 91ms/step - loss: 0.0073 - categorical_accuracy: 1.0000
# Epoch 326/1000
# 8/8 [==============================] - 1s 91ms/step - loss: 0.0079 - categorical_accuracy: 1.0000
# Epoch 327/1000
# 8/8 [==============================] - 1s 89ms/step - loss: 0.0062 - categorical_accuracy: 1.0000
# Epoch 328/1000
# 8/8 [==============================] - 1s 89ms/step - loss: 0.0066 - categorical_accuracy: 1.0000
# Epoch 329/1000
# 8/8 [==============================] - 1s 88ms/step - loss: 0.0087 - categorical_accuracy: 1.0000
# Epoch 330/1000
# 8/8 [==============================] - 1s 92ms/step - loss: 0.0059 - categorical_accuracy: 1.0000
# Epoch 331/1000
# 8/8 [==============================] - 1s 90ms/step - loss: 0.0050 - categorical_accuracy: 1.0000
# Epoch 332/1000
# 8/8 [==============================] - 1s 88ms/step - loss: 0.0041 - categorical_accuracy: 1.0000
# Epoch 333/1000
# 8/8 [==============================] - 1s 89ms/step - loss: 0.0042 - categorical_accuracy: 1.0000
# Epoch 334/1000
# 8/8 [==============================] - 1s 88ms/step - loss: 0.0033 - categorical_accuracy: 1.0000
# Epoch 335/1000
# 8/8 [==============================] - 1s 87ms/step - loss: 0.0032 - categorical_accuracy: 1.0000
# Epoch 336/1000
# 8/8 [==============================] - 1s 89ms/step - loss: 0.0061 - categorical_accuracy: 1.0000
# Epoch 337/1000
# 8/8 [==============================] - 1s 90ms/step - loss: 0.0041 - categorical_accuracy: 1.0000
# Epoch 338/1000
# 8/8 [==============================] - 1s 89ms/step - loss: 0.0028 - categorical_accuracy: 1.0000
# Epoch 339/1000
# 8/8 [==============================] - 1s 76ms/step - loss: 0.0032 - categorical_accuracy: 1.0000
# Epoch 340/1000
# 8/8 [==============================] - 1s 98ms/step - loss: 0.0031 - categorical_accuracy: 1.0000
# Epoch 341/1000
# 8/8 [==============================] - 1s 99ms/step - loss: 0.0024 - categorical_accuracy: 1.0000
# Epoch 342/1000
# 8/8 [==============================] - 1s 90ms/step - loss: 0.0025 - categorical_accuracy: 1.0000
# Epoch 343/1000
# 8/8 [==============================] - 1s 88ms/step - loss: 0.0022 - categorical_accuracy: 1.0000
# Epoch 344/1000
# 8/8 [==============================] - 1s 93ms/step - loss: 0.0018 - categorical_accuracy: 1.0000
# Epoch 345/1000
# 8/8 [==============================] - 1s 94ms/step - loss: 0.0018 - categorical_accuracy: 1.0000
# Epoch 346/1000
# 8/8 [==============================] - 1s 95ms/step - loss: 0.0016 - categorical_accuracy: 1.0000
# Epoch 347/1000
# 8/8 [==============================] - 1s 96ms/step - loss: 0.0015 - categorical_accuracy: 1.0000
# Epoch 348/1000
# 8/8 [==============================] - 1s 96ms/step - loss: 0.0014 - categorical_accuracy: 1.0000
# Epoch 349/1000
# 8/8 [==============================] - 1s 96ms/step - loss: 0.0014 - categorical_accuracy: 1.0000
# Epoch 350/1000
# 8/8 [==============================] - 1s 96ms/step - loss: 0.0013 - categorical_accuracy: 1.0000
# Epoch 351/1000
# 8/8 [==============================] - 1s 90ms/step - loss: 0.0013 - categorical_accuracy: 1.0000
# Epoch 352/1000
# 8/8 [==============================] - 1s 89ms/step - loss: 0.0013 - categorical_accuracy: 1.0000
# Epoch 353/1000
# 8/8 [==============================] - 1s 92ms/step - loss: 0.0012 - categorical_accuracy: 1.0000
# Epoch 354/1000
# 8/8 [==============================] - 1s 88ms/step - loss: 0.0012 - categorical_accuracy: 1.0000
# Epoch 355/1000
# 8/8 [==============================] - 1s 90ms/step - loss: 0.0012 - categorical_accuracy: 1.0000
# Epoch 356/1000
# 8/8 [==============================] - 1s 89ms/step - loss: 0.0012 - categorical_accuracy: 1.0000
# Epoch 357/1000
# 8/8 [==============================] - 1s 62ms/step - loss: 0.0011 - categorical_accuracy: 1.0000
# Epoch 358/1000
# 8/8 [==============================] - 0s 55ms/step - loss: 0.0010 - categorical_accuracy: 1.0000
# Epoch 359/1000
# 8/8 [==============================] - 0s 59ms/step - loss: 9.7581e-04 - categorical_accuracy: 1.0000
# Epoch 360/1000
# 8/8 [==============================] - 0s 62ms/step - loss: 9.4439e-04 - categorical_accuracy: 1.0000
# Epoch 361/1000
# 8/8 [==============================] - 0s 61ms/step - loss: 9.1594e-04 - categorical_accuracy: 1.0000
# Epoch 362/1000
# 8/8 [==============================] - 0s 61ms/step - loss: 9.0149e-04 - categorical_accuracy: 1.0000
# Epoch 363/1000
# 8/8 [==============================] - 0s 60ms/step - loss: 8.7211e-04 - categorical_accuracy: 1.0000
# Epoch 364/1000
# 8/8 [==============================] - 0s 61ms/step - loss: 8.6177e-04 - categorical_accuracy: 1.0000
# Epoch 365/1000
# 8/8 [==============================] - 1s 77ms/step - loss: 8.2792e-04 - categorical_accuracy: 1.0000
# Epoch 366/1000
# 8/8 [==============================] - 1s 76ms/step - loss: 8.0875e-04 - categorical_accuracy: 1.0000
# Epoch 367/1000
# 8/8 [==============================] - 1s 76ms/step - loss: 8.0313e-04 - categorical_accuracy: 1.0000
# Epoch 368/1000
# 8/8 [==============================] - 1s 76ms/step - loss: 7.6901e-04 - categorical_accuracy: 1.0000
# Epoch 369/1000
# 8/8 [==============================] - 1s 76ms/step - loss: 7.4985e-04 - categorical_accuracy: 1.0000
# Epoch 370/1000
# 8/8 [==============================] - 1s 70ms/step - loss: 7.5882e-04 - categorical_accuracy: 1.0000
# Epoch 371/1000
# 8/8 [==============================] - 0s 48ms/step - loss: 7.1380e-04 - categorical_accuracy: 1.0000
# Epoch 372/1000
# 8/8 [==============================] - 0s 56ms/step - loss: 7.2835e-04 - categorical_accuracy: 1.0000
# Epoch 373/1000
# 8/8 [==============================] - 0s 50ms/step - loss: 6.9125e-04 - categorical_accuracy: 1.0000
# Epoch 374/1000
# 8/8 [==============================] - 0s 59ms/step - loss: 6.9918e-04 - categorical_accuracy: 1.0000
# Epoch 375/1000
# 8/8 [==============================] - 1s 105ms/step - loss: 6.5421e-04 - categorical_accuracy: 1.0000
# Epoch 376/1000
# 8/8 [==============================] - 0s 60ms/step - loss: 6.2988e-04 - categorical_accuracy: 1.0000
# Epoch 377/1000
# 8/8 [==============================] - 0s 60ms/step - loss: 6.1199e-04 - categorical_accuracy: 1.0000
# Epoch 378/1000
# 8/8 [==============================] - 0s 60ms/step - loss: 5.9851e-04 - categorical_accuracy: 1.0000
# Epoch 379/1000
# 8/8 [==============================] - 0s 60ms/step - loss: 6.1163e-04 - categorical_accuracy: 1.0000
# Epoch 380/1000
# 8/8 [==============================] - 0s 61ms/step - loss: 5.8053e-04 - categorical_accuracy: 1.0000
# Epoch 381/1000
# 8/8 [==============================] - 0s 60ms/step - loss: 5.6748e-04 - categorical_accuracy: 1.0000
# Epoch 382/1000
# 8/8 [==============================] - 0s 60ms/step - loss: 5.4608e-04 - categorical_accuracy: 1.0000
# Epoch 383/1000
# 8/8 [==============================] - 1s 76ms/step - loss: 5.2873e-04 - categorical_accuracy: 1.0000
# Epoch 384/1000
# 8/8 [==============================] - 1s 103ms/step - loss: 5.2180e-04 - categorical_accuracy: 1.0000
# Epoch 385/1000
# 8/8 [==============================] - 1s 94ms/step - loss: 5.1191e-04 - categorical_accuracy: 1.0000
# Epoch 386/1000
# 8/8 [==============================] - 0s 55ms/step - loss: 5.0127e-04 - categorical_accuracy: 1.0000
# Epoch 387/1000
# 8/8 [==============================] - 0s 57ms/step - loss: 4.8104e-04 - categorical_accuracy: 1.0000
# Epoch 388/1000
# 8/8 [==============================] - 0s 54ms/step - loss: 4.7946e-04 - categorical_accuracy: 1.0000
# Epoch 389/1000
# 8/8 [==============================] - 1s 82ms/step - loss: 4.7302e-04 - categorical_accuracy: 1.0000
# Epoch 390/1000
# 8/8 [==============================] - 0s 46ms/step - loss: 4.5900e-04 - categorical_accuracy: 1.0000
# Epoch 391/1000
# 8/8 [==============================] - 0s 46ms/step - loss: 4.5064e-04 - categorical_accuracy: 1.0000
# Epoch 392/1000
# 8/8 [==============================] - 1s 106ms/step - loss: 4.4150e-04 - categorical_accuracy: 1.0000
# Epoch 393/1000
# 8/8 [==============================] - 1s 103ms/step - loss: 4.4303e-04 - categorical_accuracy: 1.0000
# Epoch 394/1000
# 8/8 [==============================] - 0s 53ms/step - loss: 4.3328e-04 - categorical_accuracy: 1.0000
# Epoch 395/1000
# 8/8 [==============================] - 0s 44ms/step - loss: 4.1922e-04 - categorical_accuracy: 1.0000
# Epoch 396/1000
# 8/8 [==============================] - 0s 46ms/step - loss: 4.1132e-04 - categorical_accuracy: 1.0000
# Epoch 397/1000
# 8/8 [==============================] - 1s 96ms/step - loss: 4.1435e-04 - categorical_accuracy: 1.0000
# Epoch 398/1000
# 8/8 [==============================] - 1s 95ms/step - loss: 4.0238e-04 - categorical_accuracy: 1.0000
# Epoch 399/1000
# 8/8 [==============================] - 1s 95ms/step - loss: 3.8589e-04 - categorical_accuracy: 1.0000
# Epoch 400/1000
# 8/8 [==============================] - 1s 95ms/step - loss: 3.8376e-04 - categorical_accuracy: 1.0000
# Epoch 401/1000
# 8/8 [==============================] - 1s 87ms/step - loss: 3.7328e-04 - categorical_accuracy: 1.0000
# Epoch 402/1000
# 8/8 [==============================] - 1s 85ms/step - loss: 3.7090e-04 - categorical_accuracy: 1.0000
# Epoch 403/1000
# 8/8 [==============================] - 0s 49ms/step - loss: 3.6232e-04 - categorical_accuracy: 1.0000
# Epoch 404/1000
# 8/8 [==============================] - 0s 49ms/step - loss: 3.6919e-04 - categorical_accuracy: 1.0000
# Epoch 405/1000
# 8/8 [==============================] - 1s 65ms/step - loss: 3.5312e-04 - categorical_accuracy: 1.0000
# Epoch 406/1000
# 8/8 [==============================] - 1s 64ms/step - loss: 3.4533e-04 - categorical_accuracy: 1.0000
# Epoch 407/1000
# 8/8 [==============================] - 1s 65ms/step - loss: 3.3608e-04 - categorical_accuracy: 1.0000
# Epoch 408/1000
# 8/8 [==============================] - 1s 63ms/step - loss: 3.2952e-04 - categorical_accuracy: 1.0000
# Epoch 409/1000
# 8/8 [==============================] - 1s 63ms/step - loss: 3.3082e-04 - categorical_accuracy: 1.0000
# Epoch 410/1000
# 8/8 [==============================] - 1s 75ms/step - loss: 3.1943e-04 - categorical_accuracy: 1.0000
# Epoch 411/1000
# 8/8 [==============================] - 1s 74ms/step - loss: 3.1865e-04 - categorical_accuracy: 1.0000
# Epoch 412/1000
# 8/8 [==============================] - 1s 76ms/step - loss: 3.1368e-04 - categorical_accuracy: 1.0000
# Epoch 413/1000
# 8/8 [==============================] - 1s 77ms/step - loss: 3.0812e-04 - categorical_accuracy: 1.0000
# Epoch 414/1000
# 8/8 [==============================] - 1s 77ms/step - loss: 3.0025e-04 - categorical_accuracy: 1.0000
# Epoch 415/1000
# 8/8 [==============================] - 1s 76ms/step - loss: 2.9312e-04 - categorical_accuracy: 1.0000
# Epoch 416/1000
# 8/8 [==============================] - 1s 76ms/step - loss: 2.9763e-04 - categorical_accuracy: 1.0000
# Epoch 417/1000
# 8/8 [==============================] - 1s 76ms/step - loss: 2.9114e-04 - categorical_accuracy: 1.0000
# Epoch 418/1000
# 8/8 [==============================] - 1s 77ms/step - loss: 2.8670e-04 - categorical_accuracy: 1.0000
# Epoch 419/1000
# 8/8 [==============================] - 1s 75ms/step - loss: 2.7653e-04 - categorical_accuracy: 1.0000
# Epoch 420/1000
# 8/8 [==============================] - 1s 75ms/step - loss: 2.7339e-04 - categorical_accuracy: 1.0000
# Epoch 421/1000
# 8/8 [==============================] - 1s 75ms/step - loss: 2.6725e-04 - categorical_accuracy: 1.0000
# Epoch 422/1000
# 8/8 [==============================] - 1s 75ms/step - loss: 2.6343e-04 - categorical_accuracy: 1.0000
# Epoch 423/1000
# 8/8 [==============================] - 1s 74ms/step - loss: 2.5990e-04 - categorical_accuracy: 1.0000
# Epoch 424/1000
# ...
# Epoch 862/1000
# 8/8 [==============================] - 1s 76ms/step - loss: 1.0254 - categorical_accuracy: 0.5614
# Epoch 863/1000
# 8/8 [==============================] - 1s 76ms/step - loss: 0.9007 - categorical_accuracy: 0.6360
# Epoch 864/1000
# 8/8 [==============================] - 1s 76ms/step - loss: 0.8709 - categorical_accuracy: 0.6316
# Epoch 865/1000
# 8/8 [==============================] - 1s 76ms/step - loss: 0.7884 - categorical_accuracy: 0.6228
# Epoch 866/1000
# 8/8 [==============================] - 1s 75ms/step - loss: 0.8089 - categorical_accuracy: 0.6491
# Epoch 867/1000
# 8/8 [==============================] - 1s 75ms/step - loss: 0.7304 - categorical_accuracy: 0.6711
# Epoch 868/1000
# 8/8 [==============================] - 1s 76ms/step - loss: 0.6758 - categorical_accuracy: 0.7544
# Epoch 869/1000
# 8/8 [==============================] - 1s 75ms/step - loss: 0.6161 - categorical_accuracy: 0.7982
# Epoch 870/1000
# 8/8 [==============================] - 1s 75ms/step - loss: 0.5489 - categorical_accuracy: 0.8377
# Epoch 871/1000
# 8/8 [==============================] - 1s 76ms/step - loss: 0.8018 - categorical_accuracy: 0.8684
# Epoch 872/1000
# 8/8 [==============================] - 1s 75ms/step - loss: 0.5876 - categorical_accuracy: 0.7456
# Epoch 873/1000
# 8/8 [==============================] - 1s 74ms/step - loss: 0.7077 - categorical_accuracy: 0.7675
# Epoch 874/1000
# 8/8 [==============================] - 1s 76ms/step - loss: 0.6302 - categorical_accuracy: 0.7456
# Epoch 875/1000
# 8/8 [==============================] - 1s 76ms/step - loss: 0.6020 - categorical_accuracy: 0.7632
# Epoch 876/1000
# 8/8 [==============================] - 1s 76ms/step - loss: 0.5519 - categorical_accuracy: 0.8377
# Epoch 877/1000
# 8/8 [==============================] - 1s 76ms/step - loss: 0.5118 - categorical_accuracy: 0.8114
# Epoch 878/1000
# 8/8 [==============================] - 1s 76ms/step - loss: 0.5241 - categorical_accuracy: 0.7939
# Epoch 879/1000
# 8/8 [==============================] - 1s 76ms/step - loss: 0.3362 - categorical_accuracy: 0.9035
# Epoch 880/1000
# 8/8 [==============================] - 1s 76ms/step - loss: 0.2953 - categorical_accuracy: 0.8991
# Epoch 881/1000
# 8/8 [==============================] - 1s 76ms/step - loss: 0.2482 - categorical_accuracy: 0.9211
# Epoch 882/1000
# 8/8 [==============================] - 1s 76ms/step - loss: 0.1957 - categorical_accuracy: 0.9518
# Epoch 883/1000
# 8/8 [==============================] - 1s 76ms/step - loss: 0.1846 - categorical_accuracy: 0.9605
# Epoch 884/1000
# 8/8 [==============================] - 1s 75ms/step - loss: 0.2920 - categorical_accuracy: 0.9211
# Epoch 885/1000
# 8/8 [==============================] - 1s 74ms/step - loss: 0.4574 - categorical_accuracy: 0.8465
# Epoch 886/1000
# 8/8 [==============================] - 1s 75ms/step - loss: 0.4710 - categorical_accuracy: 0.8114
# Epoch 887/1000
# 8/8 [==============================] - 1s 76ms/step - loss: 0.3423 - categorical_accuracy: 0.8816
# Epoch 888/1000
# 8/8 [==============================] - 1s 76ms/step - loss: 0.2337 - categorical_accuracy: 0.9474
# Epoch 889/1000
# 8/8 [==============================] - 1s 75ms/step - loss: 0.2980 - categorical_accuracy: 0.9167
# Epoch 890/1000
# 8/8 [==============================] - 1s 76ms/step - loss: 0.2525 - categorical_accuracy: 0.9254
# Epoch 891/1000
# 8/8 [==============================] - 1s 75ms/step - loss: 0.2933 - categorical_accuracy: 0.8991
# Epoch 892/1000
# 8/8 [==============================] - 1s 76ms/step - loss: 0.1954 - categorical_accuracy: 0.9342
# Epoch 893/1000
# 8/8 [==============================] - 1s 76ms/step - loss: 0.1558 - categorical_accuracy: 0.9430
# Epoch 894/1000
# 8/8 [==============================] - 1s 76ms/step - loss: 0.1249 - categorical_accuracy: 0.9649
# Epoch 895/1000
# 8/8 [==============================] - 1s 75ms/step - loss: 0.1730 - categorical_accuracy: 0.9254
# Epoch 896/1000
# 8/8 [==============================] - 1s 76ms/step - loss: 0.1794 - categorical_accuracy: 0.9211
# Epoch 897/1000
# 8/8 [==============================] - 1s 76ms/step - loss: 0.2612 - categorical_accuracy: 0.9298
# Epoch 898/1000
# 8/8 [==============================] - 1s 76ms/step - loss: 0.6369 - categorical_accuracy: 0.8377
# Epoch 899/1000
# 8/8 [==============================] - 1s 76ms/step - loss: 0.4552 - categorical_accuracy: 0.8333
# Epoch 900/1000
# 8/8 [==============================] - 1s 76ms/step - loss: 0.2570 - categorical_accuracy: 0.9737
# Epoch 901/1000
# 8/8 [==============================] - 1s 75ms/step - loss: 0.1399 - categorical_accuracy: 0.9693
# Epoch 902/1000
# 8/8 [==============================] - 1s 76ms/step - loss: 0.1332 - categorical_accuracy: 0.9737
# Epoch 903/1000
# 8/8 [==============================] - 1s 76ms/step - loss: 0.1247 - categorical_accuracy: 0.9825
# Epoch 904/1000
# 8/8 [==============================] - 1s 76ms/step - loss: 0.0837 - categorical_accuracy: 0.9737
# Epoch 905/1000
# 8/8 [==============================] - 1s 76ms/step - loss: 0.0752 - categorical_accuracy: 0.9825
# Epoch 906/1000
# 8/8 [==============================] - 1s 76ms/step - loss: 0.0579 - categorical_accuracy: 0.9912
# Epoch 907/1000
# 8/8 [==============================] - 1s 76ms/step - loss: 0.0557 - categorical_accuracy: 0.9912
# Epoch 908/1000
# 8/8 [==============================] - 1s 76ms/step - loss: 0.0429 - categorical_accuracy: 0.9912
# Epoch 909/1000
# 8/8 [==============================] - 1s 75ms/step - loss: 0.0392 - categorical_accuracy: 0.9956
# Epoch 910/1000
# 8/8 [==============================] - 1s 75ms/step - loss: 0.0262 - categorical_accuracy: 0.9956
# Epoch 911/1000
# 8/8 [==============================] - 1s 76ms/step - loss: 0.0227 - categorical_accuracy: 0.9956
# Epoch 912/1000
# 8/8 [==============================] - 1s 76ms/step - loss: 0.0190 - categorical_accuracy: 0.9956
# Epoch 913/1000
# 8/8 [==============================] - 1s 102ms/step - loss: 0.0162 - categorical_accuracy: 0.9956
# Epoch 914/1000
# 8/8 [==============================] - 1s 95ms/step - loss: 0.0141 - categorical_accuracy: 0.9956
# Epoch 915/1000
# 8/8 [==============================] - 1s 93ms/step - loss: 0.0124 - categorical_accuracy: 0.9956
# Epoch 916/1000
# 8/8 [==============================] - 1s 93ms/step - loss: 0.0109 - categorical_accuracy: 0.9956
# Epoch 917/1000
# 8/8 [==============================] - 1s 92ms/step - loss: 0.0093 - categorical_accuracy: 1.0000
# Epoch 918/1000
# 8/8 [==============================] - 1s 96ms/step - loss: 0.0083 - categorical_accuracy: 1.0000
# Epoch 919/1000
# 8/8 [==============================] - 1s 94ms/step - loss: 0.0071 - categorical_accuracy: 1.0000
# Epoch 920/1000
# 8/8 [==============================] - 1s 102ms/step - loss: 0.0060 - categorical_accuracy: 1.0000
# Epoch 921/1000
# 8/8 [==============================] - 1s 93ms/step - loss: 0.0050 - categorical_accuracy: 1.0000
# Epoch 922/1000
# 8/8 [==============================] - 1s 91ms/step - loss: 0.0042 - categorical_accuracy: 1.0000
# Epoch 923/1000
# 8/8 [==============================] - 1s 92ms/step - loss: 0.0036 - categorical_accuracy: 1.0000
# Epoch 924/1000
# 8/8 [==============================] - 1s 100ms/step - loss: 0.0032 - categorical_accuracy: 1.0000
# Epoch 925/1000
# 8/8 [==============================] - 1s 100ms/step - loss: 0.0028 - categorical_accuracy: 1.0000
# Epoch 926/1000
# 8/8 [==============================] - 1s 97ms/step - loss: 0.0025 - categorical_accuracy: 1.0000
# Epoch 927/1000
# 8/8 [==============================] - 1s 88ms/step - loss: 0.0022 - categorical_accuracy: 1.0000
# Epoch 928/1000
# 8/8 [==============================] - 1s 88ms/step - loss: 0.0020 - categorical_accuracy: 1.0000
# Epoch 929/1000
# 8/8 [==============================] - 1s 89ms/step - loss: 0.0018 - categorical_accuracy: 1.0000
# Epoch 930/1000
# 8/8 [==============================] - 1s 87ms/step - loss: 0.0016 - categorical_accuracy: 1.0000
# Epoch 931/1000
# 8/8 [==============================] - 1s 89ms/step - loss: 0.0015 - categorical_accuracy: 1.0000
# Epoch 932/1000
# 8/8 [==============================] - 1s 90ms/step - loss: 0.0013 - categorical_accuracy: 1.0000
# Epoch 933/1000
# 8/8 [==============================] - 1s 89ms/step - loss: 0.0012 - categorical_accuracy: 1.0000
# Epoch 934/1000
# 8/8 [==============================] - 1s 98ms/step - loss: 0.0011 - categorical_accuracy: 1.0000
# Epoch 935/1000
# 8/8 [==============================] - 1s 99ms/step - loss: 0.0010 - categorical_accuracy: 1.0000
# Epoch 936/1000
# 8/8 [==============================] - 1s 95ms/step - loss: 9.4369e-04 - categorical_accuracy: 1.0000
# Epoch 937/1000
# 8/8 [==============================] - 1s 91ms/step - loss: 8.9441e-04 - categorical_accuracy: 1.0000
# Epoch 938/1000
# 8/8 [==============================] - 1s 89ms/step - loss: 8.2620e-04 - categorical_accuracy: 1.0000
# Epoch 939/1000
# 8/8 [==============================] - 1s 91ms/step - loss: 7.6718e-04 - categorical_accuracy: 1.0000
# Epoch 940/1000
# 8/8 [==============================] - 1s 93ms/step - loss: 7.2890e-04 - categorical_accuracy: 1.0000
# Epoch 941/1000
# 8/8 [==============================] - 1s 91ms/step - loss: 6.9305e-04 - categorical_accuracy: 1.0000
# Epoch 942/1000
# 8/8 [==============================] - 1s 89ms/step - loss: 6.4598e-04 - categorical_accuracy: 1.0000
# Epoch 943/1000
# 8/8 [==============================] - 1s 94ms/step - loss: 6.2010e-04 - categorical_accuracy: 1.0000
# Epoch 944/1000
# 8/8 [==============================] - 1s 95ms/step - loss: 5.8343e-04 - categorical_accuracy: 1.0000
# Epoch 945/1000
# 8/8 [==============================] - 1s 95ms/step - loss: 5.4887e-04 - categorical_accuracy: 1.0000
# Epoch 946/1000
# 8/8 [==============================] - 1s 96ms/step - loss: 5.1434e-04 - categorical_accuracy: 1.0000
# Epoch 947/1000
# 8/8 [==============================] - 1s 94ms/step - loss: 4.8737e-04 - categorical_accuracy: 1.0000
# Epoch 948/1000
# 8/8 [==============================] - 1s 96ms/step - loss: 4.5827e-04 - categorical_accuracy: 1.0000
# Epoch 949/1000
# 8/8 [==============================] - 1s 94ms/step - loss: 4.3647e-04 - categorical_accuracy: 1.0000
# Epoch 950/1000
# 8/8 [==============================] - 1s 94ms/step - loss: 4.1526e-04 - categorical_accuracy: 1.0000
# Epoch 951/1000
# 8/8 [==============================] - 1s 95ms/step - loss: 3.9553e-04 - categorical_accuracy: 1.0000
# Epoch 952/1000
# 8/8 [==============================] - 1s 95ms/step - loss: 3.7519e-04 - categorical_accuracy: 1.0000
# Epoch 953/1000
# 8/8 [==============================] - 1s 95ms/step - loss: 3.5823e-04 - categorical_accuracy: 1.0000
# Epoch 954/1000
# 8/8 [==============================] - 1s 95ms/step - loss: 3.4008e-04 - categorical_accuracy: 1.0000
# Epoch 955/1000
# 8/8 [==============================] - 1s 93ms/step - loss: 3.3040e-04 - categorical_accuracy: 1.0000
# Epoch 956/1000
# 8/8 [==============================] - 1s 92ms/step - loss: 2.9437e-04 - categorical_accuracy: 1.0000
# Epoch 957/1000
# 8/8 [==============================] - 1s 90ms/step - loss: 2.8323e-04 - categorical_accuracy: 1.0000
# Epoch 958/1000
# 8/8 [==============================] - 1s 91ms/step - loss: 2.7122e-04 - categorical_accuracy: 1.0000
# Epoch 959/1000
# 8/8 [==============================] - 1s 90ms/step - loss: 2.5914e-04 - categorical_accuracy: 1.0000
# Epoch 960/1000
# 8/8 [==============================] - 1s 90ms/step - loss: 2.5040e-04 - categorical_accuracy: 1.0000
# Epoch 961/1000
# 8/8 [==============================] - 1s 89ms/step - loss: 2.3974e-04 - categorical_accuracy: 1.0000
# Epoch 962/1000
# 8/8 [==============================] - 1s 91ms/step - loss: 2.3150e-04 - categorical_accuracy: 1.0000
# Epoch 963/1000
# 8/8 [==============================] - 1s 89ms/step - loss: 2.2381e-04 - categorical_accuracy: 1.0000
# Epoch 964/1000
# 8/8 [==============================] - 1s 89ms/step - loss: 2.1637e-04 - categorical_accuracy: 1.0000
# Epoch 965/1000
# 8/8 [==============================] - 1s 90ms/step - loss: 2.0961e-04 - categorical_accuracy: 1.0000
# Epoch 966/1000
# 8/8 [==============================] - 1s 88ms/step - loss: 2.0297e-04 - categorical_accuracy: 1.0000
# Epoch 967/1000
# 8/8 [==============================] - 1s 90ms/step - loss: 1.9605e-04 - categorical_accuracy: 1.0000
# Epoch 968/1000
# 8/8 [==============================] - 1s 90ms/step - loss: 1.8812e-04 - categorical_accuracy: 1.0000
# Epoch 969/1000
# 8/8 [==============================] - 1s 91ms/step - loss: 1.8116e-04 - categorical_accuracy: 1.0000
# Epoch 970/1000
# 8/8 [==============================] - 1s 93ms/step - loss: 1.7496e-04 - categorical_accuracy: 1.0000
# Epoch 971/1000
# 8/8 [==============================] - 1s 91ms/step - loss: 1.7014e-04 - categorical_accuracy: 1.0000
# Epoch 972/1000
# 8/8 [==============================] - 1s 95ms/step - loss: 1.6520e-04 - categorical_accuracy: 1.0000
# Epoch 973/1000
# 8/8 [==============================] - 1s 103ms/step - loss: 1.6015e-04 - categorical_accuracy: 1.0000
# Epoch 974/1000
# 8/8 [==============================] - 1s 100ms/step - loss: 1.5537e-04 - categorical_accuracy: 1.0000
# Epoch 975/1000
# 8/8 [==============================] - 1s 99ms/step - loss: 1.5110e-04 - categorical_accuracy: 1.0000
# Epoch 976/1000
# 8/8 [==============================] - 1s 90ms/step - loss: 1.4683e-04 - categorical_accuracy: 1.0000
# Epoch 977/1000
# 8/8 [==============================] - 1s 88ms/step - loss: 1.4241e-04 - categorical_accuracy: 1.0000
# Epoch 978/1000
# 8/8 [==============================] - 1s 88ms/step - loss: 1.3795e-04 - categorical_accuracy: 1.0000
# Epoch 979/1000
# 8/8 [==============================] - 1s 94ms/step - loss: 1.3360e-04 - categorical_accuracy: 1.0000
# Epoch 980/1000
# 8/8 [==============================] - 1s 88ms/step - loss: 1.3001e-04 - categorical_accuracy: 1.0000
# Epoch 981/1000
# 8/8 [==============================] - 1s 89ms/step - loss: 1.2677e-04 - categorical_accuracy: 1.0000
# Epoch 982/1000
# 8/8 [==============================] - 1s 90ms/step - loss: 1.2343e-04 - categorical_accuracy: 1.0000
# Epoch 983/1000
# 8/8 [==============================] - 1s 88ms/step - loss: 1.2080e-04 - categorical_accuracy: 1.0000
# Epoch 984/1000
# 8/8 [==============================] - 1s 89ms/step - loss: 1.1803e-04 - categorical_accuracy: 1.0000
# Epoch 985/1000
# 8/8 [==============================] - 1s 88ms/step - loss: 1.1554e-04 - categorical_accuracy: 1.0000
# Epoch 986/1000
# 8/8 [==============================] - 1s 91ms/step - loss: 1.1322e-04 - categorical_accuracy: 1.0000
# Epoch 987/1000
# 8/8 [==============================] - 1s 88ms/step - loss: 1.1215e-04 - categorical_accuracy: 1.0000
# Epoch 988/1000
# 8/8 [==============================] - 1s 91ms/step - loss: 1.0900e-04 - categorical_accuracy: 1.0000
# Epoch 989/1000
# 8/8 [==============================] - 1s 90ms/step - loss: 1.0604e-04 - categorical_accuracy: 1.0000
# Epoch 990/1000
# 8/8 [==============================] - 1s 89ms/step - loss: 1.0317e-04 - categorical_accuracy: 1.0000
# Epoch 991/1000
# 8/8 [==============================] - 1s 89ms/step - loss: 1.0026e-04 - categorical_accuracy: 1.0000
# Epoch 992/1000
# 8/8 [==============================] - 1s 94ms/step - loss: 9.8054e-05 - categorical_accuracy: 1.0000
# Epoch 993/1000
# 8/8 [==============================] - 1s 92ms/step - loss: 9.6034e-05 - categorical_accuracy: 1.0000
# Epoch 994/1000
# 8/8 [==============================] - 1s 90ms/step - loss: 9.3637e-05 - categorical_accuracy: 1.0000
# Epoch 995/1000
# 8/8 [==============================] - 1s 87ms/step - loss: 9.1267e-05 - categorical_accuracy: 1.0000
# Epoch 996/1000
# 8/8 [==============================] - 1s 94ms/step - loss: 8.9196e-05 - categorical_accuracy: 1.0000
# Epoch 997/1000
# 8/8 [==============================] - 1s 88ms/step - loss: 8.7167e-05 - categorical_accuracy: 1.0000
# Epoch 998/1000
# 8/8 [==============================] - 1s 87ms/step - loss: 8.5685e-05 - categorical_accuracy: 1.0000
# Epoch 999/1000
# 8/8 [==============================] - 1s 87ms/step - loss: 8.3804e-05 - categorical_accuracy: 1.0000
# Epoch 1000/1000
# 8/8 [==============================] - 1s 89ms/step - loss: 8.2145e-05 - categorical_accuracy: 1.0000

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm (LSTM)                 (None, 30, 64)            48896
#
#  lstm_1 (LSTM)               (None, 30, 128)           98816
#
#  lstm_2 (LSTM)               (None, 64)                49408
#
#  dense (Dense)               (None, 64)                4160
#
#  dense_1 (Dense)             (None, 32)                2080
#
#  dense_2 (Dense)             (None, 8)                 264
#
# =================================================================
# Total params: 203,624
# Trainable params: 203,624
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# # 8. Make Predictions

# %%
res = model.predict(X_test)
# Out:
# 1/1 [==============================] - 1s 661ms/step

# %%
actions[np.argmax(res[3])]
# Out:
# 'hello'

# %%
actions[np.argmax(y_test[3])]
# Out:
# 'hello'

# %% [markdown]
# # 9. Save Weights

# %%
model.save('action.h5')

# %%
#del model

# %%
model.load_weights('action.h5')

# %% [markdown]
# # 10. Evaluation using Confusion Matrix and Accuracy

# %%
from sklearn.metrics import multilabel_confusion_matrix, accuracy_score

# %%
yhat = model.predict(X_test)
# Out:
# 1/1 [==============================] - 0s 51ms/step

# %%
ytrue = np.argmax(y_test, axis=1).tolist()
yhat = np.argmax(yhat, axis=1).tolist()

# %%
multilabel_confusion_matrix(ytrue, yhat)
# Out:
# array([[[10,  0],
#         [ 1,  1]],
#
#        [[10,  0],
#         [ 0,  2]],
#
#        [[11,  0],
#         [ 0,  1]],
#
#        [[10,  0],
#         [ 0,  2]],
#
#        [[11,  1],
#         [ 0,  0]],
#
#        [[11,  0],
#         [ 0,  1]],
#
#        [[ 8,  0],
#         [ 0,  4]]], dtype=int64)

# %%
accuracy_score(ytrue, yhat)
# Out:
# 0.9166666666666666

# %% [markdown]
# # 11. Test in Real Time

# %%
from scipy import stats

# %%
colors = [(245,117,16), (117,245,16), (16,117,245)]
def prob_viz(res, actions, input_frame, colors):
    output_frame = input_frame.copy()
    for num, prob in enumerate(res):
        cv2.rectangle(output_frame, (0,60+num*40), (int(prob*100), 90+num*40), colors[num], -1)
        cv2.putText(output_frame, actions[num], (0, 85+num*40), cv2.FONT_HERSHEY_SIMPLEX, 1, (255,255,255), 2, cv2.LINE_AA)
        
    return output_frame

# %%
plt.figure(figsize=(18,18))
plt.imshow(prob_viz(res, actions, image, colors))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_11416\104962489.py in <module>
#       1 plt.figure(figsize=(18,18))
# ----> 2 plt.imshow(prob_viz(res, actions, image, colors))
#
# ~\AppData\Local\Temp\ipykernel_11416\2568779431.py in prob_viz(res, actions, input_frame, colors)
#       3     output_frame = input_frame.copy()
#       4     for num, prob in enumerate(res):
# ----> 5         cv2.rectangle(output_frame, (0,60+num*40), (int(prob*100), 90+num*40), colors[num], -1)
#       6         cv2.putText(output_frame, actions[num], (0, 85+num*40), cv2.FONT_HERSHEY_SIMPLEX, 1, (255,255,255), 2, cv2.LINE_AA)
#       7
#
# TypeError: only size-1 arrays can be converted to Python scalars

# %%
# 1. New detection variables
sequence = []
sentence = []
predictions=[]
threshold = 0.8

cap = cv2.VideoCapture(0)
# Set mediapipe model 
with mp_holistic.Holistic(min_detection_confidence=0.5, min_tracking_confidence=0.5) as holistic:
    while cap.isOpened():

        # Read feed
        ret, frame = cap.read()

        # Make detections
        image, results = mediapipe_detection(frame, holistic)
        print(results)
        
        # Draw landmarks
        draw_styled_landmarks(image, results)
        
        # 2. Prediction logic
        keypoints = extract_keypoints(results)
#         sequence.insert(0,keypoints)
#         sequence = sequence[:30]
        sequence.append(keypoints)
        sequence = sequence[-30:]
        
        if len(sequence) == 30:
            res = model.predict(np.expand_dims(sequence, axis=0))[0]
            print(actions[np.argmax(res)])
            predictions.append(np.argmax(res))
            
            
        #3. Viz logic
            if res[np.argmax(res)] > threshold: 
                if len(sentence) > 0: 
                    if actions[np.argmax(res)] != sentence[-1]:
                        sentence.append(actions[np.argmax(res)])
                else:
                    sentence.append(actions[np.argmax(res)])

            if len(sentence) > 1: 
                sentence = sentence[-1:]

            # Viz probabilities
#             image = prob_viz(res, actions, image, colors)
            
        cv2.rectangle(image, (0,0), (640, 40), (245, 117, 16), -1)
        cv2.putText(image, ' '.join(sentence), (3,30), 
                       cv2.FONT_HERSHEY_SIMPLEX, 1, (255, 255, 255), 2, cv2.LINE_AA)
        
        # Show to screen
        cv2.imshow('OpenCV Feed', image)

        # Break gracefully
        if cv2.waitKey(10) & 0xFF == ord('q'):
            break
    cap.release()
    cv2.destroyAllWindows()
# Out:
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 70ms/step
# you
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 50ms/step
# you
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 35ms/step
# you
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 62ms/step
# you
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 43ms/step
# you
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 43ms/step
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 35ms/step
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 44ms/step
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 34ms/step
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 50ms/step
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 47ms/step
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 31ms/step
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 50ms/step
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 50ms/step
# no
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 33ms/step
# no
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 34ms/step
# no
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 31ms/step
# no
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 35ms/step
# no
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 50ms/step
# no
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 31ms/step
# no
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 48ms/step
# no
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 40ms/step
# no
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 33ms/step
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 44ms/step
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 42ms/step
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 42ms/step
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 48ms/step
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 47ms/step
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 33ms/step
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 32ms/step
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 51ms/step
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 31ms/step
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 32ms/step
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 45ms/step
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 32ms/step
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 37ms/step
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 35ms/step
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 30ms/step
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 31ms/step
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 34ms/step
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 48ms/step
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 31ms/step
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 31ms/step
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 33ms/step
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 49ms/step
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 33ms/step
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 32ms/step
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 46ms/step
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 30ms/step
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 49ms/step
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 49ms/step
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 50ms/step
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 51ms/step
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 46ms/step
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 49ms/step
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 36ms/step
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 35ms/step
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 30ms/step
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 33ms/step
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 41ms/step
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 48ms/step
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 50ms/step
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 43ms/step
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 45ms/step
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 51ms/step
# you
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 33ms/step
# you
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 45ms/step
# you
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 49ms/step
# you
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 38ms/step
# you
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 57ms/step
# sorry
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 51ms/step
# sorry
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 36ms/step
# sorry
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 32ms/step
# sorry
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 52ms/step
# sorry
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 45ms/step
# sorry
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 63ms/step
# sorry
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 35ms/step
# sorry
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 38ms/step
# sorry
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 35ms/step
# sorry
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 46ms/step
# sorry
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 33ms/step
# sorry
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 35ms/step
# sorry
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 47ms/step
# sorry
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 33ms/step
# sorry
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 33ms/step
# sorry
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 42ms/step
# sorry
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 42ms/step
# sorry
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 34ms/step
# sorry
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 31ms/step
# sorry
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 48ms/step
# sorry
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 45ms/step
# sorry
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 49ms/step
# sorry
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 55ms/step
# sorry
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 48ms/step
# sorry
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 34ms/step
# sorry
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 48ms/step
# sorry
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 36ms/step
# sorry
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 45ms/step
# sorry
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 47ms/step
# sorry
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 32ms/step
# sorry
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 49ms/step
# sorry
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 43ms/step
# sorry
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 37ms/step
# sorry
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 50ms/step
# sorry
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 48ms/step
# sorry
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 33ms/step
# sorry
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 38ms/step
# sorry
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 47ms/step
# sorry
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 50ms/step
# sorry
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 35ms/step
# sorry
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 32ms/step
# sorry
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 48ms/step
# sorry
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 33ms/step
# sorry
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 33ms/step
# sorry
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 46ms/step
# sorry
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 40ms/step
# sorry
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 42ms/step
# sorry
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 34ms/step
# sorry
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 33ms/step
# sorry
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 50ms/step
# sorry
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 41ms/step
# sorry
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 45ms/step
# sorry
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 49ms/step
# sorry
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 44ms/step
# sorry
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 33ms/step
# sorry
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 45ms/step
# sorry
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 48ms/step
# sorry
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 46ms/step
# thanks
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 49ms/step
# thanks
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 51ms/step
# thanks
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 34ms/step
# thanks
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 45ms/step
# thanks
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 45ms/step
# thanks
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 42ms/step
# thanks
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 43ms/step
# thanks
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 50ms/step
# thanks
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 44ms/step
# thanks
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 36ms/step
# thanks
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 47ms/step
# thanks
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 48ms/step
# thanks
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 46ms/step
# thanks
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 35ms/step
# thanks
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 36ms/step
# thanks
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 46ms/step
# thanks
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 33ms/step
# thanks
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 45ms/step
# thanks
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 62ms/step
# thanks
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 47ms/step
# thanks
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 36ms/step
# thanks
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 41ms/step
# thanks
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 63ms/step
# thanks
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 34ms/step
# thanks
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 50ms/step
# thanks
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 39ms/step
# thanks
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 43ms/step
# thanks
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 33ms/step
# thanks
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 50ms/step
# thanks
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 33ms/step
# thanks
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 47ms/step
# thanks
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 33ms/step
# thanks
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 42ms/step
# thanks
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 30ms/step
# thanks
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 33ms/step
# thanks
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 47ms/step
# thanks
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 54ms/step
# thanks
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 41ms/step
# thanks
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 32ms/step
# thanks
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 45ms/step
# thanks
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 49ms/step
# thanks
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 32ms/step
# thanks
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 47ms/step
# thanks
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 31ms/step
# thanks
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 43ms/step
# thanks
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 47ms/step
# thanks
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 51ms/step
# thanks
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 50ms/step
# thanks
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 33ms/step
# thanks
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 33ms/step
# thanks
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 33ms/step
# thanks
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 41ms/step
# thanks
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 36ms/step
# thanks
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 49ms/step
# thanks
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 50ms/step
# thanks
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 37ms/step
# thanks
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 38ms/step
# thanks
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 50ms/step
# thanks
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 47ms/step
# thanks
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 35ms/step
# thanks
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 48ms/step
# thanks
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 44ms/step
# thanks
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 41ms/step
# thanks
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 47ms/step
# thanks
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 40ms/step
# thanks
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 43ms/step
# thanks
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 47ms/step
# thanks
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 33ms/step
# thanks
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 32ms/step
# thanks
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 32ms/step
# thanks
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 47ms/step
# thanks
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 49ms/step
# thanks
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 38ms/step
# thanks
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 37ms/step
# thanks
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 49ms/step
# thanks
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 49ms/step
# thanks
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 47ms/step
# thanks
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 36ms/step
# thanks
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 33ms/step
# thanks
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 35ms/step
# thanks
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 36ms/step
# thanks
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 50ms/step
# thanks
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 34ms/step
# thanks
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 33ms/step
# thanks
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 48ms/step
# thanks
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 49ms/step
# thanks
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 45ms/step
# thanks
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 32ms/step
# thanks
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 34ms/step
# thanks
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 45ms/step
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 48ms/step
# sorry
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 34ms/step
# sorry
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 32ms/step
# you
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 34ms/step
# you
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 50ms/step
# you
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 49ms/step
# you
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 48ms/step
# you
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 48ms/step
# you
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 45ms/step
# you
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 32ms/step
# you
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 44ms/step
# you
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 37ms/step
# you
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 34ms/step
# you
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 49ms/step
# you
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 46ms/step
# you
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 61ms/step
# you
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 46ms/step
# you
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 50ms/step
# you
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 42ms/step
# you
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 52ms/step
# you
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 43ms/step
# you
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 50ms/step
# you
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 43ms/step
# you
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 41ms/step
# you
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 47ms/step
# you
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 46ms/step
# you
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 33ms/step
# you
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 33ms/step
# you
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 48ms/step
# you
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 49ms/step
# you
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 49ms/step
# you
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 47ms/step
# you
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 32ms/step
# you
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 32ms/step
# you
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 49ms/step
# you
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 33ms/step
# you
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 49ms/step
# you
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 49ms/step
# you
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 37ms/step
# you
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 34ms/step
# you
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 60ms/step
# you
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 49ms/step
# you
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 44ms/step
# you
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 35ms/step
# you
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 34ms/step
# you
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 50ms/step
# you
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 35ms/step
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 47ms/step
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 34ms/step
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 32ms/step
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 33ms/step
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 33ms/step
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 46ms/step
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 34ms/step
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 50ms/step
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 36ms/step
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 34ms/step
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 40ms/step
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 51ms/step
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 49ms/step
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 35ms/step
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 44ms/step
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 44ms/step
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 52ms/step
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 35ms/step
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 50ms/step
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 43ms/step
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 32ms/step
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 32ms/step
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 33ms/step
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 52ms/step
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 33ms/step
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 56ms/step
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 47ms/step
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 47ms/step
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 31ms/step
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 47ms/step
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 51ms/step
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 49ms/step
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 36ms/step
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 33ms/step
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 34ms/step
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 38ms/step
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 43ms/step
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 33ms/step
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 50ms/step
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 33ms/step
# you
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 35ms/step
# you
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 46ms/step
# you
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 49ms/step
# you
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 40ms/step
# you
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 50ms/step
# you
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 49ms/step
# you
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 36ms/step
# you
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 45ms/step
# you
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 32ms/step
# you
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 41ms/step
# you
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 49ms/step
# you
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 50ms/step
# you
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 49ms/step
# you
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 49ms/step
# you
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 33ms/step
# you
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 43ms/step
# you
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 39ms/step
# you
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 45ms/step
# you
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 51ms/step
# you
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 34ms/step
# you
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 43ms/step
# you
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 35ms/step
# you
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 36ms/step
# you
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 32ms/step
# you
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 44ms/step
# you
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 47ms/step
# you
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 33ms/step
# you
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 49ms/step
# you
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 44ms/step
# you
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 36ms/step
# you
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 34ms/step
# you
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 49ms/step
# you
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 44ms/step
# you
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 45ms/step
# you
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 45ms/step
# you
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 34ms/step
# you
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 45ms/step
# you
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 33ms/step
# you
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 38ms/step
# you
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 49ms/step
# you
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 51ms/step
# you
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 41ms/step
# you
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 37ms/step
# yes
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 51ms/step
# yes
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 32ms/step
# yes
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 35ms/step
# yes
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 49ms/step
# yes
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 32ms/step
# yes
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 57ms/step
# yes
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 32ms/step
# Luck
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 52ms/step
# Luck
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 49ms/step
# sorry
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 32ms/step
# sorry
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 35ms/step
# sorry
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 44ms/step
# sorry
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 40ms/step
# sorry
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 48ms/step
# sorry
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 36ms/step
# sorry
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 36ms/step
# sorry
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 46ms/step
# sorry
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 34ms/step
# sorry
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 33ms/step
# sorry
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 34ms/step
# sorry
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 46ms/step
# sorry
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 43ms/step
# sorry
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 49ms/step
# sorry
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 37ms/step
# sorry
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 33ms/step
# sorry
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 34ms/step
# sorry
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 46ms/step
# sorry
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 49ms/step
# sorry
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 44ms/step
# sorry
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 34ms/step
# sorry
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 43ms/step
# sorry
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 46ms/step
# sorry
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 51ms/step
# sorry
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 42ms/step
# sorry
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 37ms/step
# sorry
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 49ms/step
# sorry
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 32ms/step
# sorry
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 50ms/step
# sorry
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 34ms/step
# sorry
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 50ms/step
# sorry
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 33ms/step
# sorry
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 35ms/step
# sorry
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 32ms/step
